# %%
# Khai báo các thư viện cần thiết
import torch
import gym
import numpy as np
from gym.spaces import Discrete
import random
import os
import pickle
from collections import deque
import torch.nn as nn
import torch.nn.functional as F

# %%
# Meta model

class MetaModelNet(nn.Module):
    """
    Mạng nơron cho mô hình MetaModelNet.
    """
    def __init__(self, local_size, num_classes):
        super(MetaModelNet, self).__init__()
    
        # Tầng CNN cho local_obs
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)

        # Tầng FC cho position
        self.fc_position = nn.Linear(2, 32)

        # Tầng FC cuối cùng
        self.fc1 = nn.Linear(256 * local_size * local_size + 32, 512)
        self.fc2 = nn.Linear(512, 256)
        
        # Dropout trước tầng FC cuối cùng
        self.dropout = nn.Dropout(0.5)
        # Tầng đầu ra
        self.fc3 = nn.Linear(256, num_classes)

    def forward(self, local_obs, position):
        """
        Hàm truyền dữ liệu qua mạng nơron.
        
        :param local_obs: Dữ liệu đầu vào (local observations).
        :param position: Vị trí của dữ liệu đầu vào.
        :return: Kết quả đầu ra của mạng nơron.
        """

        # Xử lý local_obs qua các tầng CNN
        x_local = F.relu(self.conv1(local_obs))
        x_local = F.relu(self.conv2(x_local))
        x_local = F.relu(self.conv3(x_local))
        x_local = F.relu(self.conv4(x_local))
        
        # Chuyển đổi kích thước tensor
        x_local = x_local.view(x_local.size(0), -1)  # Chuyển đổi thành vector 1 chiều

        # Xử lý position qua tầng FC
        x_position = F.relu(self.fc_position(position))

        # Kết hợp dữ liệu từ local_obs và position
        x = torch.cat((x_local, x_position), dim=1)

        # Truyền qua các tầng FC
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x

# %%
# Model cho MazeNet

class MazeNetCombined(nn.Module):
    def __init__(self, local_size=11, global_size=10, num_actions=4):
        super(MazeNetCombined, self).__init__()
        
        # Quan sát cục bộ
        self.conv1_local = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2_local = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3_local = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4_local = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        
        # Quan sát toàn cục
        self.conv1_global = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2_global = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3_global = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4_global = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        
        # Fully Connected cho vị trí hiện tại
        self.fc_position = nn.Linear(2, 32)

        # Tầng Fully Connected cuối cùng
        self.fc1 = nn.Linear(256 * local_size * local_size + 256 * global_size * global_size + 32, 256)
        self.fc2 = nn.Linear(256, 128)
        self.dropout_fc = nn.Dropout(p=0.5)  # Dropout trước tầng FC3
        self.fc3 = nn.Linear(128, num_actions)

    def forward(self, local_obs, global_obs, position):
        # Xử lý local_obs
        x_local = F.relu(self.conv1_local(local_obs))
        x_local = F.relu(self.conv2_local(x_local))
        x_local = F.relu(self.conv3_local(x_local))
        x_local = F.relu(self.conv4_local(x_local))
        x_local = x_local.view(x_local.size(0), -1)
    
        # Xử lý global_obs
        x_global = F.relu(self.conv1_global(global_obs))
        x_global = F.relu(self.conv2_global(x_global))
        x_global = F.relu(self.conv3_global(x_global))
        x_global = F.relu(self.conv4_global(x_global))
        x_global = x_global.view(x_global.size(0), -1)
        # Xử lý vị trí hiện tại
        x_position = F.relu(self.fc_position(position))

        # Kết hợp tất cả
        x = torch.cat((x_local, x_global, x_position), dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout_fc(x)  # Dropout trước FC3
        x = self.fc3(x)

        return x

# %%
# Môi trường Mê cung

class MazeEnv(gym.Env):
    # Môi trường mê cung
    # Maze: Mê cung được tạo ra ngẫu nhiên với các ô đường và tường
    # Với các ô đường được đánh dấu là 0 và các ô tường được đánh dấu là -1, ô đích được đánh dấu là 2
    # Discovered_maze: Mê cung đã được khám phá trong quá trình di chuyển của tác tử
    # Với các ô đường được đánh dấu là 0, các ô tường được đánh dấu là -5, đích được đánh dấu là 10, ô chưa được khám phá được đánh dấu là 1
    # Giá trị các ô đường giảm dần mỗi lần tác tử đi qua
    # Agent_position: Vị trí hiện tại của tác tử trong mê cung
    # Base_position: Vị trí ban đầu của tác tử trong mê cung
    # Goal_position: Vị trí đích trong mê cung
    # Start_position: Vị trí bắt đầu của tác tử mỗi lần tạo mê cung mới
    # Buff: Biến để xác định xem tác tử có đang sử dụng buff senrigan hay không
    # Debuff: Biến để xác định xem tác tử có đang bị debuff shin no meiro hay không
    
    def __init__(self, maze_size, max_steps = 15, path_percent = 70):
        """
        Khởi tạo môi trường Mê cung.

        Args:
        - maze_size (int): Kích thước của mê cung (ví dụ: 50x50).
        - max_steps (int): Số bước tối đa cho mỗi tập.
        - path_percent (int): Tỷ lệ phần trăm ô đường trong mê cung (0-100).
        """
        # Đặt các thông số của môi trường

        super(MazeEnv, self).__init__()  # Kế thừa từ gym.Env
        self.data_set_name = ""
        self.data_exported_count = 0
        self.export_data = {}
        
        self.maze_size = maze_size
        self.max_steps = max_steps
        self.path_percent = path_percent

        self.maze = np.ones((maze_size, maze_size), dtype=int)  # Mặc định là chưa biết (1)
        self.goal_position = (maze_size * 5 // 6, maze_size * 5 // 6)  # Đích cố định tại giữa khu vực đích
        self.buff = False
        self.debuff = False

        # Định nghĩa action_space (0: lên, 1: xuống, 2: trái, 3: phải)
        self.action_space = Discrete(4)

    # Xuất dữ liệu mê cung
    def export_maze(self, path = "mazedata"):
        """
        Xuất dữ liệu mê cung ra tệp tin.

        Args:
        - path (str): Đường dẫn để lưu dữ liệu mê cung.
        """
        if not os.path.exists(path):
            os.makedirs(path)
        export_data = {}
        export_data['maze'] = self.maze
        export_data['start_position'] = self.start_position
        export_data['agent_end_position'] = self.agent_position
        with open(os.path.join(path, f"maze_{self.data_exported_count}.pkl"), 'wb') as f:
            pickle.dump(export_data, f)
        self.data_exported_count += 1

    # Các phương thức liên quan đến tái tạo mê cung
    def reset(self):
        self.base_position = (self.maze_size // 6 - 1, self.maze_size // 6 - 1)
        self.agent_position = self.base_position
        return self.regenerate_maze(0, self.path_percent)
    
    def regenerate_maze(self, adder = 0, path_percent = 70):
        self.start_position = self.agent_position
        self.maze = self.generate_maze(adder, path_percent)
        self.create_discovered_maze()
        self.discover_maze()
        self.export_data['local_obs'] = self.get_observation()[2:9, 2:9]
        self.export_data['agent_start_position'] = self.agent_position
        return (self.get_observation(), self.downsample(self.discovered_maze), self.agent_position)

    def generate_maze(self, adder = 0, path_percent=70):
        if self.agent_position[0] >= self.maze_size * 2 // 3 and self.agent_position[1] >= self.maze_size * 2 // 3:
            number_of_path = 1 + adder
        else:
            number_of_path = 2 + adder
            
        while True:  # Sử dụng vòng lặp để tạo lại mê cung nếu không hợp lệ
            total_cells = self.maze_size * self.maze_size
            num_paths = int(total_cells * path_percent / 100)
            num_walls = total_cells - num_paths
    
            # Tạo danh sách ngẫu nhiên các giá trị (đường hoặc tường)
            maze_values = [0] * num_paths + [-1] * num_walls
            random.shuffle(maze_values)  # Xáo trộn các giá trị
    
            # Điền vào mê cung
            self.maze = np.array(maze_values).reshape(self.maze_size, self.maze_size)
    
            # Đặt điểm bắt đầu và đích
            self.maze[self.agent_position] = 0  # Đảm bảo điểm bắt đầu là đường (0)
            self.maze[self.goal_position] = 2  # Đảm bảo điểm đích là đường (2)
    
            # Kiểm tra tính hợp lệ
            if self.validate_maze(number_of_path):
                break  # Nếu mê cung hợp lệ, thoát vòng lặp
        return self.maze

    def validate_maze(self, number_of_path = 0):
        stack = [self.agent_position]
        visited = set()
        d = 0
        
        while stack:
            x, y = stack.pop()
            if self.debuff:
                if (x, y) == self.goal_position:
                    return False

            if (x, y) == self.goal_position:
                d += 1
                if d == number_of_path:
                    return True
                continue
            
            if (x, y) in visited:
                continue
            visited.add((x, y))

            # Thêm các ô lân cận vào stack
            neighbors = self.get_neighbors(x, y)
            for nx, ny in neighbors:
                if self.maze[nx, ny] > -1 and (nx, ny) not in visited:  # Chỉ đi qua đường
                    stack.append((nx, ny))
                    
        return False or self.debuff  # Không có đường tới đích

    def get_neighbors(self, x, y):
        """
        Lấy danh sách các ô lân cận.
        """
        neighbors = []
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx < self.maze_size and 0 <= ny < self.maze_size:
                neighbors.append((nx, ny))
        return neighbors
    
    # Các phương thức liên quan đến mê cung được khám phá
    def create_discovered_maze(self):
        self.discovered_maze = np.ones((self.maze_size + 10, self.maze_size + 10), dtype = int) # Mặc định là chưa biết (1)
        self.discovered_maze[0 : 5, :] = -5
        self.discovered_maze[:, 0 : 5] = -5
        self.discovered_maze[self.maze_size + 5 : self.maze_size + 10, :] = -5
        self.discovered_maze[:, self.maze_size + 5 : self.maze_size + 10] = -5
        self.discovered_maze[self.goal_position[0] + 5, self.goal_position[1] + 5] = 10  # Đích
        
    def discover_maze(self):
        x, y = self.agent_position
        obs_size = 11  # Kích thước quan sát (11x11)
        if self.buff:
            half_size = 5
        else:
            half_size = 3

        # Xác định giới hạn của vùng quan sát trong mê cung
        min_x = max(0, x - half_size)
        max_x = min(self.maze_size, x + half_size + 1)
        min_y = max(0, y - half_size)
        max_y = min(self.maze_size, y + half_size + 1)

        # Điền dữ liệu từ mê cung vào vùng khám phá
        for x in range(min_x, max_x):
            for y in range(min_y, max_y):
                if self.discovered_maze[x + 5, y + 5] == 1:
                    self.discovered_maze[x + 5, y + 5] = self.maze[x, y] * 5
        
    # Phương thức chính để thực hiện hành động trong môi trường
    def step(self, action):
        """
        Thực hiện hành động và cập nhật trạng thái của môi trường.
    
        Args:
        - action (int): Hành động (0: lên, 1: xuống, 2: trái, 3: phải)
    
        Returns:
        - observation (np.array): Vùng quan sát quanh tác tử
        - done (bool): Trạng thái kết thúc
        """
        # Lấy vị trí hiện tại của tác tử
        x, y = self.agent_position
    
        # Xác định vị trí mới dựa trên hành động
        if action == 0:  # Lên
            new_x, new_y = x - 1, y
        elif action == 1:  # Xuống
            new_x, new_y = x + 1, y
        elif action == 2:  # Trái
            new_x, new_y = x, y - 1
        elif action == 3:  # Phải
            new_x, new_y = x, y + 1
        
        # Khởi tạo biến done
        done = False

        # Cập nhật vị trí tác tử
        if self.valid_check((new_x, new_y)):  # Nếu vị trí mới hợp lệ và không phải là tường
            # Nếu vị trí mới hợp lệ, cập nhật vị trí tác tử
            self.agent_position = (new_x, new_y)
            self.discover_maze()

            # Kiểm tra nếu đến đích
            if self.agent_position == self.goal_position:
                done = True
            
            # Giảm giá trị ô đã khám phá 
            if self.discovered_maze[new_x + 5, new_y + 5] > -5:
                self.discovered_maze[new_x + 5, new_y + 5] -= 1        
                
        # Tạo quan sát hiện tại
        local_obs = self.get_observation()

        #Tạo quan sát toàn mê cung
        global_obs = self.downsample(self.discovered_maze)

        return local_obs, global_obs, self.agent_position, done

    # Phương thức để downsample mê cung
    def downsample(self, maze, block_size = 5):
        """
        Downsample toàn bộ mê cung bằng cách lấy tổng của các ô.
    
        Args:
        - maze: Mê cung kích thước lớn (ví dụ: 50x50).
        - block_size: Kích thước mỗi khối để downsample (ví dụ: 5x5).
    
        Returns:
        - Downsampled maze.
        """
        from skimage.measure import block_reduce
        return block_reduce(maze, block_size=(block_size, block_size), func=np.sum)

    # Xuất dữ liệu mê cung
    def render(self):
        render_maze = np.zeros((self.maze_size, self.maze_size), dtype = int) 
        for i in range(self.maze_size):
            for j in range(self.maze_size):
                if self.maze[i][j] == -1:
                    render_maze[i][j] = 1
                    continue
                if self.maze[i][j] == 2:
                    render_maze[i][j] = 10
                    continue
                if self.discovered_maze[i + 5, j + 5] < 0:
                    render_maze[i][j] = 2
        print(render_maze)
    
    # Phương thức để lấy quan sát hiện tại của tác tử
    def get_observation(self):
        x, y = self.agent_position
        observation = np.zeros((11,11), dtype = int)
        observation[0 : 11, 0 : 11] = self.discovered_maze[x: x + 11, y : y + 11]
        return observation

    # Phương thức để kích hoạt buff
    def activate_buff(self, buff):
        self.regenerate_maze()
        if buff == 'senrigan':
            self.buff = True
            print("senrigan")
        else:
            self.buff = False
        if buff == 'slime-san onegai':
            print("slime-san onegai")
            self.bfs(self.agent_position, 50)
        if buff == 'tou no hikari':
            min_x = max(0, self.agent_position[0] - 10)
            max_x = min(self.maze_size, self.agent_position[0] + 11)
            min_y = max(0, self.agent_position[1] - 10)
            max_y = min(self.maze_size, self.agent_position[1] + 11)
            for x in range(min_x, max_x):
                for y in range(min_y, max_y):
                    if self.discovered_maze[x + 5, y + 5] == 1:
                        self.discovered_maze[x + 5, y + 5] = 5 * self.maze[x, y] 
            print("tou no hikari")
        if buff == 'unmei no michi':
            self.regenerate_maze(1)
            print("unmei no michi")
        return self.get_observation(), self.downsample(self.discovered_maze), self.agent_position
    
    # Phương thức để kích hoạt debuff
    def activate_debuff(self, debuff):
        if debuff == 'waamu houru':
            self.agent_position = (random.randint(self.maze_size // 3, self.maze_size), random.randint(self.maze_size // 3, self.maze_size))
        if debuff == 'shin no meiro':
            self.debuff = True
        else:
            self.debuff = False
        return self.regenerate_maze()
    
    # Thuật toán BFS phục vụ buff slime-san onegai
    def bfs(self, position, step = 50):
        """
        Thuật toán BFS (Breadth-First Search)
    
        Args:
        - position: Đỉnh bắt đầu tìm kiếm.
        - step: số bược di chuyển
    
        """
        # Tập các đỉnh đã duyệt
        visited = set()
        visited_order = []
    
        # Hàng đợi (FIFO) để quản lý các đỉnh
        queue = deque([position])
    
        # Bắt đầu duyệt đồ thị
        while queue:
            # Lấy một đỉnh từ hàng đợi
            current = queue.popleft()
            x,y = current
            
            # Kiểm tra nếu đỉnh chưa được duyệt
            if current not in visited:
                visited.add(current)
                visited_order.append(current)
                if self.discovered_maze[x + 5, y + 5] == 1:
                    self.discovered_maze[5 + x, 5 + y] = 5 * self.maze[x, y]
                if len(visited_order) >= step:
                    break
                neighbors = self.get_neighbors(x, y)
                for nx, ny in neighbors:
                    if self.maze[nx, ny] > -1 and (nx, ny) not in visited:  # Chỉ đi qua đường
                        queue.append((nx, ny))

    # Phương thức để kiểm tra tính hợp lệ của một vị trí
    def valid_check(self, p1):
        if 0 <= p1[0] < self.maze_size and 0 <= p1[1] < self.maze_size and self.maze[p1] > -1:
            return True
        return False

    # Phương thức xác định hệ số tau
    def tau_coefficient(self, coefficient = 2):
        return ((abs(self.agent_position[0] - self.goal_position[0]) + abs(self.agent_position[1] - self.goal_position[1])) / (4 / 3 * self.maze_size)) ** coefficient

# %%
# Tải model
def load_model(model_path, device = "cuda"):
    # Load the model
    model = torch.load(model_path, map_location=device, weights_only=False)
    model.eval()  # Chuyển model về chế độ đánh giá (evaluation mode)
    return model

# %%
# Tải meta-model và các model liên quan
while True:
    meta_model_path = input("Enter the meta-model name: ")
    if os.path.exists(meta_model_path + "/meta_model.pth"):
        break
    else:
        print("Meta-model not found. Please enter a valid name.")

meta_model = load_model(meta_model_path + "/meta_model.pth")

with open(meta_model_path + "/models_info.pkl", "rb") as f:
    models_info = pickle.load(f)

model_counter = 0
models = []
for model_info in models_info:
    model = load_model(model_info['model_path'])
    buff = model_info['buff']
    tau_start = model_info['tau_start']
    tau_end = model_info['tau_end']
    tau_decay = model_info['tau_decay']
    tau_decay_exponent = model_info['tau_decay_exponent']
    models.append((model, buff, tau_start, tau_end, tau_decay, tau_decay_exponent))
    model_counter += 1
    print(f"Mode path: {model_info['model_path']}, Buff: {buff}")
print(f"Loaded {model_counter} models")
# Out:
# Mode path: model01/model.pth, Buff: none
# Mode path: model02/model.pth, Buff: None
# Mode path: model04/model.pth, Buff: senrigan
# Mode path: model07/model.pth, Buff: tou no hikari
# Mode path: model10/model.pth, Buff: unmei no michi
# Mode path: model13/model.pth, Buff: slime-san onegai
# Loaded 6 models

# %%
# Khởi tạo các siêu tham số
maze_size = 30
max_steps = 15
path_percent = 70
num_actions = 4

max_episodes = 10000
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Chọn model phù hợp
def select_model(local_obs, position):
    with torch.no_grad():
        meta_model_local_obs = torch.tensor(local_obs[2:9, 2:9], dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
        position = torch.tensor(position, dtype=torch.float32).unsqueeze(0).to(device)
        # Dự đoán hành động từ mô hình meta
        action_probs = meta_model(meta_model_local_obs, position)

    # Tính xác suất Boltzmann cho mỗi mô hình
    boltzmann_probs = torch.softmax(action_probs * 10, dim = 1)
    print(f"Boltzmann probabilities: {boltzmann_probs}")
    # Chọn mô hình dựa trên xác suất Boltzmann
    model_index = torch.multinomial(boltzmann_probs, num_samples=1).item()
    model, buff, tau_start, tau_end, tau_decay, tau_coefficient = models[model_index]
    tau = tau_start * env.tau_coefficient(tau_coefficient)
    return model, buff, tau_start, tau_end, tau_decay, tau_coefficient, tau

# %%
# Chọn hành động
def select_action(env, policy_net, local_obs, global_obs, position, tau, num_actions, device):
    """
    Chọn hành động dựa trên chiến lược Boltzmann Exploration.

    Args:
    - policy_net (nn.Module): Mạng chính để dự đoán giá trị Q(s, a).
    - local_obs (np.array): Quan sát cục bộ (ví dụ: 11x11).
    - global_obs (np.array): Quan sát toàn bộ mê cung đã downsample (ví dụ: 10x10).
    - position (list or np.array): Vị trí hiện tại của tác tử (dx, dy).
    - tau (float): Xác suất chọn hành động ngẫu nhiên (khám phá).
    - num_actions (int): Số lượng hành động (ví dụ: 4: lên, xuống, trái, phải).
    - device (torch.device): Thiết bị thực thi (CPU hoặc GPU).

    Returns:
    - action (int): Hành động được chọn (0, 1, 2, 3).
    """
    p1 = (position[0] - 1, position[1])
    p2 = (position[0] + 1, position[1])
    p3 = (position[0], position[1] - 1)
    p4 = (position[0], position[1] + 1)

    # Loại bỏ các hành động không hợp lệ (nếu cần)
    valid_actions = []
    if env.valid_check(p1): valid_actions.append(0)  # Lên
    if env.valid_check(p2): valid_actions.append(1)  # Xuống
    if env.valid_check(p3): valid_actions.append(2)  # Trái
    if env.valid_check(p4): valid_actions.append(3)  # Phải

    # Chuyển đổi các quan sát thành Tensor để đưa vào mạng
    local_obs_tensor = torch.tensor(local_obs, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
    global_obs_tensor = torch.tensor(global_obs, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
    position_tensor = torch.tensor(position, dtype=torch.float32).unsqueeze(0).to(device)

    # Dự đoán giá trị Q(s, a) cho tất cả các hành động
    q_values = policy_net(local_obs_tensor, global_obs_tensor, position_tensor)

    # Lấy giá trị Q chỉ cho các hành động hợp lệ
    valid_q_values = q_values.squeeze()[valid_actions]  # Chỉ giữ Q của các hành động hợp lệ

    # Tính xác suất Boltzmann (softmax)
    probabilities = torch.softmax(valid_q_values / tau, dim=0)

    # Chọn hành động dựa trên xác suất Boltzmann
    selected_index = torch.multinomial(probabilities, num_samples=1).item()
    action = valid_actions[selected_index]
    
    return action

# %%
# Vòng lặp chạy chương trình
counter = 0
step_min = 1000
step_max = 0
done_count = 0
env = MazeEnv(maze_size=maze_size, max_steps=max_steps, path_percent=path_percent)
env.reset()

for episode in range(max_episodes):
    if counter % env.max_steps == 0:
        if counter:
            env.export_maze(meta_model_path + "/mazedata")
        # Khởi tạo trạng thái môi trường
        local_obs, global_obs, position = env.regenerate_maze()
        local_obs, global_obs, position = env.activate_buff(buff)

        # Chọn model phù hợp
        model, buff, tau_start, tau_end, tau_decay, tau_coefficient, tau = select_model(local_obs, position)
    counter += 1

    # Chọn hành động
    action = select_action(env, model, local_obs, global_obs, position, tau, num_actions, device)

    # Thực hiện hành động trong môi trường
    local_obs, global_obs, position, done = env.step(action)
    
    # Giảm tau theo thời gian
    tau = max(tau_end, tau * tau_decay)
    
    # reset môi trường nếu đạt được mục tiêu
    if done:
        env.export_maze(meta_model_path + "/mazedata")
        done_count += 1
        print(f"Done counter: {done_count}")
        print(f"Number of steps: {counter}")
        if counter > step_max:
            step_max = counter
        if counter < step_min: 
            step_min = counter
        counter = 0
        local_obs, global_obs, position = env.reset()
        local_obs, global_obs, position = env.activate_buff(buff)
        # Chọn model phù hợp
        model, buff, tau_start, tau_end, tau_decay, tau_coefficient, tau = select_model(local_obs, position)

print(f"average number of steps: {(max_episodes - counter) // done_count}")
print(f"max: {step_max}")
print(f"min: {step_min}")
# Out:
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1475, 0.1982, 0.0973, 0.4615, 0.0309, 0.0647]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.1352, 0.1783, 0.0951, 0.4958, 0.0264, 0.0693]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0497, 0.2876, 0.1110, 0.4364, 0.0569, 0.0584]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0063, 0.1185, 0.1885, 0.5814, 0.0442, 0.0611]], device='cuda:0')
# Done counter: 1
# Number of steps: 48
# senrigan
# Boltzmann probabilities: tensor([[0.2009, 0.1720, 0.0925, 0.4181, 0.0316, 0.0849]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0071, 0.3898, 0.1347, 0.4094, 0.0330, 0.0261]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0574, 0.1842, 0.0974, 0.5677, 0.0348, 0.0585]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0344, 0.2271, 0.1142, 0.5033, 0.0459, 0.0751]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0651, 0.2541, 0.1262, 0.4402, 0.0513, 0.0630]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0217, 0.1141, 0.1354, 0.3460, 0.1111, 0.2717]], device='cuda:0')
# Done counter: 2
# Number of steps: 64
# senrigan
# Boltzmann probabilities: tensor([[0.1624, 0.1849, 0.0947, 0.4413, 0.0340, 0.0826]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0234, 0.2500, 0.1371, 0.4679, 0.0504, 0.0711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1090, 0.1979, 0.1146, 0.4733, 0.0337, 0.0714]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.1257, 0.2712, 0.0893, 0.3982, 0.0619, 0.0538]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2497, 0.1526, 0.0773, 0.4086, 0.0268, 0.0850]], device='cuda:0')
# Done counter: 3
# Number of steps: 60
# tou no hikari
# Boltzmann probabilities: tensor([[0.2702, 0.1353, 0.0482, 0.4150, 0.0305, 0.1008]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0454, 0.2358, 0.1356, 0.4795, 0.0421, 0.0617]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0736, 0.2258, 0.1586, 0.4262, 0.0411, 0.0746]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1596, 0.1895, 0.1039, 0.4367, 0.0329, 0.0773]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0092, 0.2625, 0.0299, 0.4544, 0.0637, 0.1803]], device='cuda:0')
# Done counter: 4
# Number of steps: 56
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1385, 0.1963, 0.1002, 0.4535, 0.0379, 0.0735]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1149, 0.1836, 0.1006, 0.5101, 0.0273, 0.0636]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1798, 0.1659, 0.0927, 0.4585, 0.0238, 0.0792]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1444, 0.1993, 0.1087, 0.4390, 0.0340, 0.0746]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0303, 0.3696, 0.0889, 0.4206, 0.0421, 0.0485]], device='cuda:0')
# Done counter: 5
# Number of steps: 54
# unmei no michi
# Boltzmann probabilities: tensor([[0.0901, 0.1707, 0.1099, 0.5457, 0.0193, 0.0643]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1496, 0.1771, 0.1042, 0.4599, 0.0295, 0.0796]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1881, 0.1870, 0.0952, 0.4318, 0.0282, 0.0698]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2048, 0.1589, 0.0635, 0.4529, 0.0323, 0.0875]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0022, 0.1402, 0.0967, 0.5935, 0.0766, 0.0907]], device='cuda:0')
# Done counter: 6
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.1160, 0.2223, 0.1166, 0.4603, 0.0269, 0.0579]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0704, 0.2188, 0.1153, 0.5026, 0.0399, 0.0530]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1829, 0.1670, 0.0887, 0.4567, 0.0247, 0.0801]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0312, 0.2311, 0.1055, 0.4556, 0.0645, 0.1120]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0036, 0.4425, 0.0178, 0.4299, 0.0537, 0.0524]], device='cuda:0')
# Done counter: 7
# Number of steps: 50
# tou no hikari
# Boltzmann probabilities: tensor([[0.0859, 0.1652, 0.1217, 0.5367, 0.0185, 0.0719]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1268, 0.1925, 0.1045, 0.4780, 0.0320, 0.0662]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0059, 0.3316, 0.1645, 0.4181, 0.0504, 0.0296]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1042, 0.2666, 0.1097, 0.4215, 0.0496, 0.0483]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0056, 0.1113, 0.1664, 0.6087, 0.0455, 0.0626]], device='cuda:0')
# Done counter: 8
# Number of steps: 48
# unmei no michi
# Boltzmann probabilities: tensor([[0.0819, 0.1983, 0.1101, 0.5105, 0.0371, 0.0621]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1189, 0.2147, 0.1144, 0.4638, 0.0267, 0.0615]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0269, 0.1647, 0.1571, 0.6176, 0.0198, 0.0139]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0562, 0.2360, 0.1140, 0.4776, 0.0492, 0.0670]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1831, 0.1921, 0.0868, 0.4096, 0.0434, 0.0851]], device='cuda:0')
# Done counter: 9
# Number of steps: 60
# senrigan
# Boltzmann probabilities: tensor([[0.0603, 0.2083, 0.1318, 0.4975, 0.0425, 0.0596]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1666, 0.1902, 0.0951, 0.4517, 0.0321, 0.0643]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0023, 0.4353, 0.1148, 0.4168, 0.0199, 0.0109]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0065, 0.3777, 0.1384, 0.3995, 0.0448, 0.0332]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0305, 0.1190, 0.1711, 0.3881, 0.1093, 0.1820]], device='cuda:0')
# Done counter: 10
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.1386, 0.1877, 0.1090, 0.4583, 0.0332, 0.0732]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0795, 0.2238, 0.1243, 0.4556, 0.0510, 0.0659]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1125, 0.1895, 0.1090, 0.4960, 0.0268, 0.0663]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0417, 0.2896, 0.1402, 0.4169, 0.0669, 0.0447]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0169, 0.3111, 0.0797, 0.4534, 0.0481, 0.0908]], device='cuda:0')
# Done counter: 11
# Number of steps: 60
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0011, 0.5283, 0.0447, 0.4176, 0.0045, 0.0039]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1767, 0.1915, 0.1024, 0.4175, 0.0344, 0.0775]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1118, 0.2045, 0.1095, 0.4746, 0.0339, 0.0657]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0386, 0.2309, 0.1417, 0.3948, 0.0645, 0.1294]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0035, 0.1498, 0.1437, 0.5028, 0.0787, 0.1216]], device='cuda:0')
# Done counter: 12
# Number of steps: 46
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1822, 0.1858, 0.1037, 0.4304, 0.0250, 0.0729]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1170, 0.2065, 0.1202, 0.4458, 0.0369, 0.0736]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1418, 0.1942, 0.1020, 0.4618, 0.0312, 0.0690]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0696, 0.1930, 0.1298, 0.4997, 0.0342, 0.0738]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1595, 0.1930, 0.0926, 0.4405, 0.0361, 0.0783]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0058, 0.1357, 0.1083, 0.3393, 0.1539, 0.2570]], device='cuda:0')
# Done counter: 13
# Number of steps: 62
# tou no hikari
# Boltzmann probabilities: tensor([[0.0972, 0.1689, 0.1134, 0.5181, 0.0284, 0.0740]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1662, 0.1817, 0.0954, 0.4589, 0.0269, 0.0709]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1133, 0.1967, 0.1142, 0.4677, 0.0342, 0.0739]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0216, 0.1623, 0.1144, 0.5308, 0.0748, 0.0961]], device='cuda:0')
# Done counter: 14
# Number of steps: 42
# tou no hikari
# Boltzmann probabilities: tensor([[0.1784, 0.1819, 0.1013, 0.4195, 0.0320, 0.0868]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1275, 0.1758, 0.0851, 0.5052, 0.0333, 0.0731]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0950, 0.2007, 0.1142, 0.4962, 0.0301, 0.0638]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1046, 0.2369, 0.1099, 0.4315, 0.0477, 0.0695]], device='cuda:0')
# Done counter: 15
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.1586, 0.1757, 0.0989, 0.4652, 0.0261, 0.0755]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1381, 0.2008, 0.1214, 0.4451, 0.0244, 0.0702]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1904, 0.1716, 0.0983, 0.4204, 0.0315, 0.0878]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0920, 0.2067, 0.1098, 0.4938, 0.0348, 0.0629]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0026, 0.1212, 0.0853, 0.6094, 0.0680, 0.1136]], device='cuda:0')
# Done counter: 16
# Number of steps: 48
# senrigan
# Boltzmann probabilities: tensor([[0.0193, 0.1945, 0.3413, 0.3776, 0.0485, 0.0189]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1243, 0.1864, 0.1035, 0.4929, 0.0285, 0.0644]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0889, 0.2260, 0.1313, 0.4463, 0.0363, 0.0712]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0005, 0.4172, 0.0648, 0.1637, 0.3028, 0.0510]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0014, 0.3898, 0.0520, 0.4425, 0.0740, 0.0404]], device='cuda:0')
# Done counter: 17
# Number of steps: 60
# Boltzmann probabilities: tensor([[0.1339, 0.1905, 0.1048, 0.4738, 0.0299, 0.0670]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0046, 0.5282, 0.1993, 0.2306, 0.0257, 0.0116]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0458, 0.2542, 0.1123, 0.5181, 0.0265, 0.0431]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1348, 0.2222, 0.1047, 0.4236, 0.0434, 0.0714]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0025, 0.1407, 0.1054, 0.5773, 0.0760, 0.0980]], device='cuda:0')
# Done counter: 18
# Number of steps: 46
# tou no hikari
# Boltzmann probabilities: tensor([[0.1588, 0.1956, 0.1016, 0.4530, 0.0256, 0.0654]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0675, 0.1965, 0.1188, 0.5224, 0.0377, 0.0571]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.2006, 0.1666, 0.0930, 0.4207, 0.0304, 0.0887]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1635, 0.2357, 0.1181, 0.3673, 0.0476, 0.0678]], device='cuda:0')
# Done counter: 19
# Number of steps: 44
# senrigan
# Boltzmann probabilities: tensor([[0.1020, 0.1646, 0.1120, 0.5229, 0.0255, 0.0731]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.2114, 0.1573, 0.0843, 0.4374, 0.0241, 0.0854]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0486, 0.2209, 0.1155, 0.5051, 0.0367, 0.0732]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1552, 0.1926, 0.1134, 0.4270, 0.0326, 0.0793]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0587, 0.2980, 0.0892, 0.4637, 0.0447, 0.0457]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0015, 0.2163, 0.1324, 0.4893, 0.1087, 0.0519]], device='cuda:0')
# Done counter: 20
# Number of steps: 64
# tou no hikari
# Boltzmann probabilities: tensor([[0.0526, 0.2146, 0.1279, 0.5107, 0.0396, 0.0545]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1196, 0.1962, 0.1083, 0.4731, 0.0323, 0.0705]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.2218, 0.1623, 0.0866, 0.4193, 0.0271, 0.0829]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0074, 0.3157, 0.2157, 0.4137, 0.0232, 0.0243]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0252, 0.1998, 0.1381, 0.5034, 0.0440, 0.0894]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[1.2852e-04, 3.5450e-01, 1.3506e-01, 3.9761e-01, 1.0500e-01, 7.7058e-03]],
#        device='cuda:0')
# Boltzmann probabilities: tensor([[2.7595e-05, 3.9465e-01, 8.7527e-02, 4.2164e-01, 9.3291e-02, 2.8562e-03]],
#        device='cuda:0')
# Done counter: 21
# Number of steps: 78
# tou no hikari
# Boltzmann probabilities: tensor([[0.0367, 0.2525, 0.1242, 0.4780, 0.0641, 0.0446]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0435, 0.2019, 0.1330, 0.5556, 0.0246, 0.0415]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1892, 0.1915, 0.0977, 0.4245, 0.0278, 0.0694]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0579, 0.2198, 0.1262, 0.4726, 0.0479, 0.0756]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0946, 0.2170, 0.1207, 0.4497, 0.0471, 0.0709]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0051, 0.3994, 0.1041, 0.3678, 0.0784, 0.0452]], device='cuda:0')
# Done counter: 22
# Number of steps: 66
# tou no hikari
# Boltzmann probabilities: tensor([[0.1110, 0.1803, 0.0991, 0.5116, 0.0313, 0.0666]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1198, 0.1839, 0.1050, 0.5014, 0.0267, 0.0633]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0106, 0.2711, 0.2122, 0.3559, 0.0928, 0.0573]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0749, 0.2887, 0.1185, 0.4091, 0.0563, 0.0525]], device='cuda:0')
# Boltzmann probabilities: tensor([[4.5029e-05, 4.0092e-01, 1.1705e-01, 3.7681e-01, 1.0142e-01, 3.7506e-03]],
#        device='cuda:0')
# Done counter: 23
# Number of steps: 46
# senrigan
# Boltzmann probabilities: tensor([[0.1347, 0.1681, 0.1090, 0.4792, 0.0252, 0.0838]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1229, 0.1765, 0.1014, 0.5085, 0.0230, 0.0678]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1767, 0.1865, 0.0974, 0.4297, 0.0329, 0.0768]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0580, 0.2898, 0.0983, 0.4395, 0.0580, 0.0564]], device='cuda:0')
# Done counter: 24
# Number of steps: 44
# tou no hikari
# Boltzmann probabilities: tensor([[0.2230, 0.1668, 0.0763, 0.4194, 0.0303, 0.0844]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0456, 0.2684, 0.1335, 0.4365, 0.0580, 0.0580]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0902, 0.1933, 0.1195, 0.5054, 0.0268, 0.0648]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1104, 0.1894, 0.1056, 0.5070, 0.0251, 0.0626]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0059, 0.1017, 0.1337, 0.6494, 0.0409, 0.0684]], device='cuda:0')
# Done counter: 25
# Number of steps: 52
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1727, 0.1650, 0.0799, 0.4657, 0.0295, 0.0872]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1617, 0.1740, 0.0919, 0.4792, 0.0228, 0.0703]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1282, 0.1957, 0.0980, 0.4859, 0.0295, 0.0627]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1502, 0.1829, 0.0942, 0.4747, 0.0283, 0.0696]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1222, 0.3095, 0.0749, 0.3617, 0.0744, 0.0571]], device='cuda:0')
# Done counter: 26
# Number of steps: 56
# tou no hikari
# Boltzmann probabilities: tensor([[0.1865, 0.1676, 0.0736, 0.4707, 0.0271, 0.0745]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0854, 0.2280, 0.1162, 0.4718, 0.0337, 0.0649]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1192, 0.1966, 0.1122, 0.4757, 0.0289, 0.0674]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0770, 0.2592, 0.1196, 0.4491, 0.0419, 0.0532]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0038, 0.1742, 0.2110, 0.4150, 0.0860, 0.1100]], device='cuda:0')
# Done counter: 27
# Number of steps: 46
# senrigan
# Boltzmann probabilities: tensor([[0.1659, 0.1604, 0.0931, 0.4846, 0.0207, 0.0753]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1065, 0.1801, 0.0905, 0.5441, 0.0237, 0.0551]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1557, 0.1844, 0.1003, 0.4639, 0.0261, 0.0695]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1200, 0.2098, 0.1127, 0.4400, 0.0408, 0.0766]], device='cuda:0')
# Done counter: 28
# Number of steps: 42
# senrigan
# Boltzmann probabilities: tensor([[0.1407, 0.1888, 0.0970, 0.4781, 0.0284, 0.0670]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0251, 0.1602, 0.2879, 0.4225, 0.0592, 0.0451]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0909, 0.2221, 0.1131, 0.4654, 0.0442, 0.0644]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1889, 0.1604, 0.0823, 0.4671, 0.0244, 0.0768]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0980, 0.2088, 0.1155, 0.4709, 0.0384, 0.0684]], device='cuda:0')
# Done counter: 29
# Number of steps: 60
# tou no hikari
# Boltzmann probabilities: tensor([[0.1306, 0.1889, 0.0976, 0.5030, 0.0215, 0.0584]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0566, 0.2670, 0.1333, 0.4465, 0.0371, 0.0595]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1589, 0.1884, 0.0992, 0.4547, 0.0287, 0.0701]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2030, 0.1756, 0.0987, 0.4260, 0.0229, 0.0739]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1049, 0.2598, 0.1121, 0.4010, 0.0566, 0.0656]], device='cuda:0')
# Done counter: 30
# Number of steps: 60
# Boltzmann probabilities: tensor([[0.2163, 0.1637, 0.0764, 0.4509, 0.0232, 0.0696]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2102, 0.1732, 0.0909, 0.4180, 0.0271, 0.0806]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1460, 0.1954, 0.0979, 0.4689, 0.0283, 0.0635]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0412, 0.2912, 0.1024, 0.4548, 0.0514, 0.0589]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0070, 0.1229, 0.1662, 0.5540, 0.0478, 0.1022]], device='cuda:0')
# Done counter: 31
# Number of steps: 48
# tou no hikari
# Boltzmann probabilities: tensor([[0.2014, 0.1715, 0.0780, 0.4540, 0.0251, 0.0700]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0126, 0.1577, 0.0922, 0.7119, 0.0107, 0.0149]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1324, 0.1876, 0.0993, 0.4873, 0.0274, 0.0659]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0992, 0.1887, 0.0859, 0.5432, 0.0257, 0.0573]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0374, 0.3154, 0.0815, 0.4394, 0.0568, 0.0695]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[1.6542e-04, 3.6659e-01, 2.5679e-01, 2.6060e-01, 1.0889e-01, 6.9674e-03]],
#        device='cuda:0')
# Done counter: 32
# Number of steps: 64
# Boltzmann probabilities: tensor([[0.1309, 0.1792, 0.1062, 0.4873, 0.0261, 0.0703]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0318, 0.3031, 0.1413, 0.3957, 0.0721, 0.0560]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0787, 0.2126, 0.1341, 0.4638, 0.0431, 0.0677]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0114, 0.3794, 0.1463, 0.3810, 0.0648, 0.0171]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0068, 0.1233, 0.1694, 0.5695, 0.0468, 0.0841]], device='cuda:0')
# Done counter: 33
# Number of steps: 50
# tou no hikari
# Boltzmann probabilities: tensor([[0.0369, 0.3233, 0.1006, 0.4071, 0.0785, 0.0537]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1787, 0.1874, 0.1114, 0.4259, 0.0234, 0.0732]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0225, 0.2052, 0.2409, 0.4759, 0.0345, 0.0211]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0861, 0.2576, 0.1021, 0.4495, 0.0451, 0.0596]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0052, 0.3203, 0.0245, 0.4452, 0.0517, 0.1532]], device='cuda:0')
# Done counter: 34
# Number of steps: 50
# tou no hikari
# Boltzmann probabilities: tensor([[0.0985, 0.1886, 0.1140, 0.4884, 0.0369, 0.0737]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0074, 0.2576, 0.2765, 0.0507, 0.3937, 0.0142]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1472, 0.1964, 0.1021, 0.4488, 0.0339, 0.0716]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1911, 0.1781, 0.0863, 0.4224, 0.0354, 0.0866]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0302, 0.1650, 0.1509, 0.4206, 0.1092, 0.1243]], device='cuda:0')
# Done counter: 35
# Number of steps: 50
# tou no hikari
# Boltzmann probabilities: tensor([[0.1822, 0.1727, 0.0856, 0.4571, 0.0261, 0.0763]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1832, 0.1762, 0.0937, 0.4487, 0.0260, 0.0722]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1391, 0.1803, 0.1151, 0.4523, 0.0295, 0.0838]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0914, 0.2373, 0.1067, 0.4618, 0.0409, 0.0619]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0103, 0.3263, 0.0411, 0.4240, 0.0633, 0.1351]], device='cuda:0')
# Done counter: 36
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0778, 0.2096, 0.1184, 0.5050, 0.0322, 0.0568]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0877, 0.2132, 0.1253, 0.4690, 0.0399, 0.0649]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1439, 0.1683, 0.0991, 0.4891, 0.0236, 0.0760]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0493, 0.2880, 0.1235, 0.4153, 0.0554, 0.0685]], device='cuda:0')
# Done counter: 37
# Number of steps: 42
# senrigan
# Boltzmann probabilities: tensor([[0.0692, 0.2278, 0.1227, 0.4863, 0.0359, 0.0581]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0757, 0.2045, 0.1150, 0.4899, 0.0469, 0.0681]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0669, 0.2095, 0.1282, 0.4844, 0.0488, 0.0622]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0078, 0.1712, 0.0910, 0.7050, 0.0138, 0.0112]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0270, 0.2707, 0.0760, 0.4255, 0.0574, 0.1435]], device='cuda:0')
# Done counter: 38
# Number of steps: 52
# unmei no michi
# Boltzmann probabilities: tensor([[0.0820, 0.2008, 0.1125, 0.5136, 0.0325, 0.0585]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0727, 0.2072, 0.1239, 0.4899, 0.0457, 0.0606]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1619, 0.1667, 0.0978, 0.4721, 0.0239, 0.0776]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0404, 0.3317, 0.1161, 0.4048, 0.0680, 0.0390]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0290, 0.2891, 0.1092, 0.4781, 0.0477, 0.0468]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0039, 0.1201, 0.5073, 0.3016, 0.0410, 0.0261]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0035, 0.3478, 0.0129, 0.4089, 0.0582, 0.1687]], device='cuda:0')
# Done counter: 39
# Number of steps: 82
# Boltzmann probabilities: tensor([[0.0489, 0.2348, 0.1317, 0.4714, 0.0576, 0.0556]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1581, 0.1778, 0.0887, 0.4816, 0.0245, 0.0693]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1441, 0.1758, 0.1099, 0.4561, 0.0291, 0.0850]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0092, 0.3082, 0.1051, 0.4561, 0.0534, 0.0679]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0789, 0.2628, 0.1163, 0.4245, 0.0535, 0.0639]], device='cuda:0')
# Done counter: 40
# Number of steps: 56
# unmei no michi
# Boltzmann probabilities: tensor([[0.1182, 0.1962, 0.1187, 0.4723, 0.0257, 0.0688]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1984, 0.1639, 0.0846, 0.4607, 0.0216, 0.0707]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0645, 0.2357, 0.1167, 0.4698, 0.0522, 0.0611]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1091, 0.2284, 0.0962, 0.4740, 0.0372, 0.0552]], device='cuda:0')
# Done counter: 41
# Number of steps: 44
# senrigan
# Boltzmann probabilities: tensor([[0.1616, 0.1785, 0.1079, 0.4512, 0.0246, 0.0762]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1586, 0.1807, 0.1020, 0.4518, 0.0290, 0.0779]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0307, 0.1916, 0.1318, 0.5409, 0.0439, 0.0611]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0696, 0.2874, 0.1022, 0.4375, 0.0504, 0.0530]], device='cuda:0')
# Done counter: 42
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.1618, 0.1765, 0.0950, 0.4741, 0.0260, 0.0665]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1541, 0.1869, 0.0980, 0.4675, 0.0265, 0.0671]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0687, 0.2138, 0.1474, 0.4699, 0.0283, 0.0719]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1049, 0.2706, 0.0957, 0.4259, 0.0487, 0.0542]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[3.0621e-05, 3.9634e-01, 9.1772e-02, 4.1217e-01, 9.6628e-02, 3.0606e-03]],
#        device='cuda:0')
# Done counter: 43
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.2216, 0.1654, 0.0812, 0.4160, 0.0296, 0.0862]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.2217, 0.1521, 0.0585, 0.4416, 0.0328, 0.0934]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2303, 0.1603, 0.0761, 0.4028, 0.0353, 0.0953]], device='cuda:0')
# Boltzmann probabilities: tensor([[9.8545e-05, 1.8965e-01, 3.0609e-01, 1.1741e-01, 3.5848e-01, 2.8264e-02]],
#        device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0683, 0.2613, 0.1085, 0.4493, 0.0547, 0.0579]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0116, 0.3220, 0.0546, 0.5326, 0.0604, 0.0188]], device='cuda:0')
# Done counter: 44
# Number of steps: 70
# Boltzmann probabilities: tensor([[0.0017, 0.2934, 0.2285, 0.4451, 0.0267, 0.0046]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1906, 0.1764, 0.0916, 0.4429, 0.0240, 0.0745]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1216, 0.1902, 0.1039, 0.4878, 0.0288, 0.0677]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1543, 0.2718, 0.1080, 0.3569, 0.0526, 0.0564]], device='cuda:0')
# Done counter: 45
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0455, 0.2403, 0.1097, 0.5479, 0.0225, 0.0340]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0515, 0.2077, 0.1297, 0.4890, 0.0380, 0.0842]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0033, 0.4447, 0.1113, 0.4083, 0.0196, 0.0128]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0423, 0.2423, 0.1382, 0.4695, 0.0471, 0.0606]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0310, 0.1649, 0.1392, 0.4314, 0.1059, 0.1276]], device='cuda:0')
# Done counter: 46
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0069, 0.2950, 0.0996, 0.5702, 0.0217, 0.0066]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1186, 0.1852, 0.1093, 0.4870, 0.0275, 0.0724]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0050, 0.1456, 0.1017, 0.7418, 0.0034, 0.0025]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0011, 0.5075, 0.0603, 0.3400, 0.0332, 0.0580]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0004, 0.3131, 0.3091, 0.2566, 0.1077, 0.0131]], device='cuda:0')
# Done counter: 47
# Number of steps: 46
# tou no hikari
# Boltzmann probabilities: tensor([[0.0098, 0.3133, 0.2291, 0.2589, 0.1325, 0.0563]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1404, 0.1566, 0.0877, 0.4853, 0.0328, 0.0972]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0850, 0.2215, 0.1395, 0.4501, 0.0310, 0.0728]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1043, 0.2446, 0.0986, 0.4415, 0.0481, 0.0629]], device='cuda:0')
# Done counter: 48
# Number of steps: 44
# tou no hikari
# Boltzmann probabilities: tensor([[0.1941, 0.1694, 0.0988, 0.4254, 0.0290, 0.0832]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0026, 0.1259, 0.3844, 0.4672, 0.0133, 0.0066]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1184, 0.1981, 0.1094, 0.4781, 0.0297, 0.0663]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[1.3369e-06, 1.0603e-02, 7.2059e-02, 1.3831e-02, 8.9536e-01, 8.1415e-03]],
#        device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.2117, 0.1642, 0.0725, 0.4324, 0.0318, 0.0874]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1400, 0.2472, 0.0943, 0.4126, 0.0455, 0.0604]], device='cuda:0')
# Done counter: 49
# Number of steps: 74
# tou no hikari
# Boltzmann probabilities: tensor([[0.0870, 0.1972, 0.1138, 0.5057, 0.0343, 0.0621]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0806, 0.2154, 0.1298, 0.4992, 0.0252, 0.0498]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1206, 0.1956, 0.1191, 0.4431, 0.0386, 0.0830]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.1793, 0.1765, 0.0886, 0.4557, 0.0271, 0.0727]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0735, 0.2947, 0.1112, 0.4158, 0.0530, 0.0518]], device='cuda:0')
# Done counter: 50
# Number of steps: 58
# unmei no michi
# Boltzmann probabilities: tensor([[0.1750, 0.1675, 0.0683, 0.4797, 0.0304, 0.0790]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1303, 0.1772, 0.0999, 0.5048, 0.0246, 0.0632]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1479, 0.1929, 0.1027, 0.4522, 0.0321, 0.0722]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0503, 0.3542, 0.0831, 0.4150, 0.0491, 0.0483]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[8.4445e-05, 3.9531e-01, 1.7466e-01, 3.1930e-01, 1.0555e-01, 5.0906e-03]],
#        device='cuda:0')
# Boltzmann probabilities: tensor([[1.7709e-04, 3.6262e-01, 2.6749e-01, 2.5374e-01, 1.0882e-01, 7.1602e-03]],
#        device='cuda:0')
# Done counter: 51
# Number of steps: 62
# tou no hikari
# Boltzmann probabilities: tensor([[0.2211, 0.1708, 0.0989, 0.3990, 0.0266, 0.0834]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1971, 0.1741, 0.0756, 0.4466, 0.0287, 0.0779]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[1.6449e-04, 1.6455e-01, 5.0288e-01, 9.4165e-02, 2.2534e-01, 1.2902e-02]],
#        device='cuda:0')
# Boltzmann probabilities: tensor([[0.0719, 0.2014, 0.1202, 0.5160, 0.0351, 0.0554]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0253, 0.3239, 0.0680, 0.4471, 0.0533, 0.0825]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0252, 0.2635, 0.0475, 0.3489, 0.0642, 0.2507]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0040, 0.1397, 0.1436, 0.4950, 0.0777, 0.1401]], device='cuda:0')
# Done counter: 52
# Number of steps: 76
# tou no hikari
# Boltzmann probabilities: tensor([[0.0550, 0.2361, 0.1146, 0.5224, 0.0237, 0.0482]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1035, 0.1818, 0.1091, 0.4977, 0.0365, 0.0715]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0575, 0.1954, 0.1139, 0.5219, 0.0364, 0.0749]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1644, 0.1883, 0.1004, 0.4500, 0.0274, 0.0694]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0088, 0.3774, 0.0473, 0.4591, 0.0545, 0.0529]], device='cuda:0')
# Done counter: 53
# Number of steps: 54
# tou no hikari
# Boltzmann probabilities: tensor([[0.1574, 0.1698, 0.0819, 0.5091, 0.0209, 0.0609]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0929, 0.1963, 0.1326, 0.4705, 0.0318, 0.0759]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0662, 0.2166, 0.1174, 0.5046, 0.0341, 0.0609]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0385, 0.1760, 0.1539, 0.5570, 0.0364, 0.0382]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0100, 0.3625, 0.0371, 0.4647, 0.0688, 0.0568]], device='cuda:0')
# Done counter: 54
# Number of steps: 56
# tou no hikari
# Boltzmann probabilities: tensor([[0.1696, 0.1974, 0.0983, 0.4432, 0.0267, 0.0648]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0523, 0.1851, 0.1352, 0.5337, 0.0315, 0.0621]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1589, 0.1764, 0.0980, 0.4660, 0.0265, 0.0743]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0334, 0.2190, 0.1168, 0.5011, 0.0445, 0.0852]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0157, 0.2423, 0.0602, 0.5001, 0.0804, 0.1013]], device='cuda:0')
# Done counter: 55
# Number of steps: 58
# Boltzmann probabilities: tensor([[0.0078, 0.3838, 0.1183, 0.4390, 0.0269, 0.0243]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1452, 0.1729, 0.0950, 0.5044, 0.0195, 0.0630]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1478, 0.1752, 0.2283, 0.3698, 0.0526, 0.0263]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1466, 0.1919, 0.0987, 0.4569, 0.0333, 0.0725]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0113, 0.5214, 0.0487, 0.3143, 0.0514, 0.0528]], device='cuda:0')
# Done counter: 56
# Number of steps: 52
# tou no hikari
# Boltzmann probabilities: tensor([[0.1350, 0.1773, 0.1041, 0.4936, 0.0221, 0.0679]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.1046, 0.2116, 0.1161, 0.4837, 0.0241, 0.0600]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1749, 0.1935, 0.1010, 0.4181, 0.0358, 0.0768]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0821, 0.2360, 0.1671, 0.4059, 0.0505, 0.0583]], device='cuda:0')
# Done counter: 57
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.1148, 0.2015, 0.1127, 0.4606, 0.0374, 0.0730]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1597, 0.1766, 0.0945, 0.4756, 0.0240, 0.0695]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1916, 0.1813, 0.0947, 0.4322, 0.0275, 0.0727]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1823, 0.1812, 0.0983, 0.4303, 0.0300, 0.0779]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0872, 0.3283, 0.1070, 0.3708, 0.0604, 0.0462]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0033, 0.4556, 0.0116, 0.3791, 0.0577, 0.0927]], device='cuda:0')
# Done counter: 58
# Number of steps: 68
# Boltzmann probabilities: tensor([[0.0266, 0.1783, 0.1058, 0.5398, 0.0384, 0.1110]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0051, 0.1072, 0.1242, 0.7537, 0.0064, 0.0033]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.2161, 0.1667, 0.0893, 0.4314, 0.0228, 0.0737]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0793, 0.2941, 0.1141, 0.4014, 0.0622, 0.0489]], device='cuda:0')
# Done counter: 59
# Number of steps: 44
# unmei no michi
# Boltzmann probabilities: tensor([[0.0904, 0.1993, 0.1271, 0.5113, 0.0178, 0.0541]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1607, 0.1715, 0.0795, 0.4830, 0.0292, 0.0760]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1388, 0.1849, 0.1062, 0.4672, 0.0288, 0.0741]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0883, 0.2784, 0.1126, 0.4125, 0.0536, 0.0545]], device='cuda:0')
# Done counter: 60
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0562, 0.2272, 0.1170, 0.5055, 0.0405, 0.0535]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1643, 0.1774, 0.0930, 0.4622, 0.0274, 0.0757]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0158, 0.2266, 0.1060, 0.4608, 0.0865, 0.1042]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1561, 0.1834, 0.0930, 0.4719, 0.0274, 0.0682]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0883, 0.2898, 0.1156, 0.3868, 0.0672, 0.0523]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[2.3274e-04, 3.4643e-01, 1.7607e-01, 3.5319e-01, 1.1317e-01, 1.0918e-02]],
#        device='cuda:0')
# Done counter: 61
# Number of steps: 64
# tou no hikari
# Boltzmann probabilities: tensor([[0.1200, 0.1583, 0.0862, 0.5426, 0.0208, 0.0720]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1001, 0.2083, 0.1214, 0.4526, 0.0450, 0.0726]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1722, 0.1683, 0.0904, 0.4675, 0.0248, 0.0768]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0672, 0.1995, 0.1136, 0.5242, 0.0324, 0.0631]], device='cuda:0')
# Done counter: 62
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.1655, 0.1587, 0.0793, 0.4788, 0.0276, 0.0901]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.1830, 0.1709, 0.0890, 0.4545, 0.0266, 0.0760]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.2207, 0.1642, 0.0821, 0.4307, 0.0258, 0.0766]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1449, 0.2537, 0.0895, 0.3980, 0.0490, 0.0648]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0578, 0.2868, 0.0788, 0.4702, 0.0531, 0.0532]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0160, 0.3166, 0.0683, 0.4175, 0.0570, 0.1246]], device='cuda:0')
# Done counter: 63
# Number of steps: 72
# tou no hikari
# Boltzmann probabilities: tensor([[0.0874, 0.2164, 0.1318, 0.4652, 0.0315, 0.0677]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0893, 0.1970, 0.1089, 0.5089, 0.0371, 0.0587]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1135, 0.2003, 0.1079, 0.4824, 0.0309, 0.0650]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0828, 0.2691, 0.1008, 0.4276, 0.0602, 0.0595]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0599, 0.3190, 0.0886, 0.4268, 0.0545, 0.0513]], device='cuda:0')
# Done counter: 64
# Number of steps: 58
# Boltzmann probabilities: tensor([[0.0060, 0.1492, 0.0887, 0.7466, 0.0045, 0.0050]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1475, 0.1745, 0.0985, 0.4878, 0.0225, 0.0693]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1418, 0.2184, 0.1081, 0.4411, 0.0295, 0.0611]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1813, 0.1704, 0.0854, 0.4473, 0.0304, 0.0853]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0018, 0.4063, 0.0668, 0.4980, 0.0172, 0.0100]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1869, 0.1758, 0.0795, 0.4573, 0.0291, 0.0715]], device='cuda:0')
# Done counter: 65
# Number of steps: 72
# Boltzmann probabilities: tensor([[0.0132, 0.1542, 0.0889, 0.7204, 0.0093, 0.0140]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0274, 0.2030, 0.1105, 0.6255, 0.0153, 0.0183]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1537, 0.2077, 0.1090, 0.4291, 0.0318, 0.0687]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1599, 0.1798, 0.0912, 0.4543, 0.0351, 0.0798]], device='cuda:0')
# Done counter: 66
# Number of steps: 44
# tou no hikari
# Boltzmann probabilities: tensor([[0.0894, 0.2143, 0.1087, 0.4995, 0.0304, 0.0577]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1720, 0.1720, 0.0828, 0.4689, 0.0314, 0.0730]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1276, 0.1989, 0.1103, 0.4495, 0.0379, 0.0759]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0990, 0.2419, 0.0975, 0.4494, 0.0489, 0.0633]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0706, 0.3002, 0.0888, 0.4132, 0.0634, 0.0638]], device='cuda:0')
# Done counter: 67
# Number of steps: 56
# senrigan
# Boltzmann probabilities: tensor([[0.1538, 0.1746, 0.0934, 0.4846, 0.0263, 0.0674]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0330, 0.4023, 0.1158, 0.3057, 0.0927, 0.0505]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1863, 0.1669, 0.0782, 0.4612, 0.0271, 0.0803]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1266, 0.2134, 0.0967, 0.4544, 0.0389, 0.0700]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0349, 0.2864, 0.0937, 0.4230, 0.0556, 0.1064]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1398, 0.1746, 0.0959, 0.4927, 0.0255, 0.0714]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0030, 0.2131, 0.2316, 0.3693, 0.1045, 0.0785]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[2.8670e-06, 3.1898e-01, 1.8012e-02, 5.9349e-01, 6.8652e-02, 8.6559e-04]],
#        device='cuda:0')
# Done counter: 68
# Number of steps: 92
# unmei no michi
# Boltzmann probabilities: tensor([[0.1479, 0.1810, 0.1008, 0.4691, 0.0270, 0.0741]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1407, 0.2060, 0.1127, 0.4629, 0.0244, 0.0534]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1531, 0.1773, 0.0968, 0.4749, 0.0259, 0.0721]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1329, 0.2398, 0.1015, 0.4170, 0.0442, 0.0645]], device='cuda:0')
# Done counter: 69
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.1995, 0.1828, 0.0905, 0.4260, 0.0318, 0.0694]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1037, 0.1833, 0.1079, 0.5156, 0.0242, 0.0653]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1306, 0.2065, 0.1075, 0.4659, 0.0272, 0.0623]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1724, 0.1720, 0.0822, 0.4634, 0.0283, 0.0816]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[2.4717e-05, 2.3951e-01, 1.6372e-01, 6.8165e-02, 5.1917e-01, 9.4125e-03]],
#        device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0052, 0.3437, 0.0490, 0.5246, 0.0539, 0.0236]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0012, 0.2616, 0.0025, 0.4964, 0.0692, 0.1691]], device='cuda:0')
# Done counter: 70
# Number of steps: 82
# tou no hikari
# Boltzmann probabilities: tensor([[0.1430, 0.1910, 0.1096, 0.4660, 0.0232, 0.0673]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1841, 0.1709, 0.0929, 0.4561, 0.0231, 0.0729]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0191, 0.1788, 0.1128, 0.6588, 0.0136, 0.0169]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1453, 0.2132, 0.1002, 0.4285, 0.0406, 0.0722]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0065, 0.1086, 0.1511, 0.6099, 0.0484, 0.0755]], device='cuda:0')
# Done counter: 71
# Number of steps: 52
# tou no hikari
# Boltzmann probabilities: tensor([[0.1155, 0.2077, 0.1058, 0.4732, 0.0343, 0.0636]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0073, 0.1825, 0.3281, 0.4439, 0.0254, 0.0127]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1037, 0.2231, 0.1161, 0.4900, 0.0241, 0.0430]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0880, 0.2041, 0.1220, 0.4831, 0.0346, 0.0681]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0519, 0.2808, 0.1110, 0.4496, 0.0520, 0.0548]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[1.1427e-04, 3.8458e-01, 2.0773e-01, 2.9382e-01, 1.0786e-01, 5.8949e-03]],
#        device='cuda:0')
# Done counter: 72
# Number of steps: 68
# tou no hikari
# Boltzmann probabilities: tensor([[0.1464, 0.1762, 0.0940, 0.4801, 0.0285, 0.0748]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0940, 0.2225, 0.1171, 0.4543, 0.0466, 0.0655]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0826, 0.2005, 0.1172, 0.5051, 0.0311, 0.0634]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0089, 0.3025, 0.0459, 0.4108, 0.0693, 0.1627]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0005, 0.2529, 0.0071, 0.4471, 0.0960, 0.1964]], device='cuda:0')
# Done counter: 73
# Number of steps: 54
# tou no hikari
# Boltzmann probabilities: tensor([[0.0610, 0.1948, 0.1232, 0.5262, 0.0365, 0.0582]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0817, 0.1885, 0.1118, 0.5174, 0.0399, 0.0606]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0685, 0.2314, 0.1268, 0.4780, 0.0372, 0.0581]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0583, 0.1943, 0.1233, 0.5089, 0.0404, 0.0748]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0999, 0.2120, 0.1169, 0.4740, 0.0332, 0.0639]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0228, 0.3349, 0.0853, 0.4068, 0.0485, 0.1017]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[2.4280e-05, 3.9216e-01, 8.1003e-02, 4.3299e-01, 9.1157e-02, 2.6583e-03]],
#        device='cuda:0')
# Done counter: 74
# Number of steps: 78
# tou no hikari
# Boltzmann probabilities: tensor([[0.0576, 0.1989, 0.1286, 0.5141, 0.0409, 0.0599]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1900, 0.1628, 0.0697, 0.4759, 0.0265, 0.0751]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.1710, 0.1708, 0.1001, 0.4487, 0.0270, 0.0824]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1066, 0.2166, 0.1202, 0.4397, 0.0438, 0.0731]], device='cuda:0')
# Done counter: 75
# Number of steps: 44
# tou no hikari
# Boltzmann probabilities: tensor([[0.1640, 0.1723, 0.0964, 0.4799, 0.0203, 0.0671]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0796, 0.1963, 0.1176, 0.5168, 0.0279, 0.0619]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1340, 0.1916, 0.1115, 0.4616, 0.0290, 0.0723]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0522, 0.2550, 0.1080, 0.4545, 0.0500, 0.0803]], device='cuda:0')
# Boltzmann probabilities: tensor([[1.9546e-05, 3.5799e-01, 5.6293e-02, 2.6808e-01, 3.1288e-01, 4.7384e-03]],
#        device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0238, 0.2237, 0.1498, 0.3749, 0.0970, 0.1308]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0448, 0.2307, 0.1340, 0.4805, 0.0482, 0.0618]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0071, 0.2601, 0.0371, 0.5011, 0.0588, 0.1358]], device='cuda:0')
# Done counter: 76
# Number of steps: 96
# tou no hikari
# Boltzmann probabilities: tensor([[0.0505, 0.1987, 0.1239, 0.5480, 0.0270, 0.0519]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.2122, 0.1675, 0.0807, 0.4235, 0.0303, 0.0858]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1720, 0.1649, 0.0911, 0.4612, 0.0279, 0.0828]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1085, 0.2638, 0.1304, 0.3848, 0.0626, 0.0499]], device='cuda:0')
# Done counter: 77
# Number of steps: 44
# unmei no michi
# Boltzmann probabilities: tensor([[0.1050, 0.1738, 0.0951, 0.5407, 0.0241, 0.0612]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1465, 0.1895, 0.1129, 0.4483, 0.0280, 0.0748]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1416, 0.1562, 0.0822, 0.5158, 0.0295, 0.0748]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0271, 0.2662, 0.0981, 0.3656, 0.0857, 0.1574]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0066, 0.3348, 0.0286, 0.4441, 0.0594, 0.1265]], device='cuda:0')
# Done counter: 78
# Number of steps: 50
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0142, 0.2260, 0.1031, 0.6290, 0.0164, 0.0112]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1473, 0.1829, 0.0924, 0.4840, 0.0282, 0.0651]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0017, 0.4090, 0.2959, 0.2025, 0.0711, 0.0198]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1503, 0.1877, 0.0971, 0.4648, 0.0300, 0.0701]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0774, 0.2323, 0.0893, 0.5050, 0.0381, 0.0580]], device='cuda:0')
# unmei no michi
# ...
# tou no hikari
# Boltzmann probabilities: tensor([[0.1720, 0.1776, 0.0874, 0.4661, 0.0262, 0.0707]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2525, 0.1545, 0.0848, 0.4018, 0.0234, 0.0829]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0728, 0.2724, 0.0807, 0.4790, 0.0437, 0.0513]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0035, 0.1536, 0.1453, 0.4922, 0.0844, 0.1210]], device='cuda:0')
# Done counter: 154
# Number of steps: 48
# senrigan
# Boltzmann probabilities: tensor([[0.1435, 0.1851, 0.0858, 0.4878, 0.0293, 0.0684]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0696, 0.1876, 0.1255, 0.5301, 0.0261, 0.0611]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1736, 0.1888, 0.0977, 0.4403, 0.0292, 0.0704]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1137, 0.3097, 0.0939, 0.3636, 0.0688, 0.0503]], device='cuda:0')
# Done counter: 155
# Number of steps: 42
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1907, 0.1522, 0.0710, 0.4876, 0.0225, 0.0760]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1615, 0.1800, 0.0959, 0.4731, 0.0236, 0.0659]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1067, 0.1826, 0.1134, 0.4997, 0.0258, 0.0719]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1324, 0.1890, 0.1048, 0.4681, 0.0319, 0.0739]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0069, 0.4859, 0.1694, 0.1273, 0.1514, 0.0590]], device='cuda:0')
# Done counter: 156
# Number of steps: 50
# senrigan
# Boltzmann probabilities: tensor([[0.0086, 0.1297, 0.0733, 0.7727, 0.0051, 0.0106]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.2419, 0.1647, 0.0657, 0.4111, 0.0364, 0.0802]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1577, 0.1861, 0.1054, 0.4471, 0.0292, 0.0744]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1632, 0.2605, 0.0951, 0.3576, 0.0618, 0.0618]], device='cuda:0')
# Done counter: 157
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.1681, 0.1796, 0.0930, 0.4659, 0.0250, 0.0684]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1674, 0.1793, 0.1068, 0.4412, 0.0266, 0.0786]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1233, 0.2026, 0.1004, 0.4774, 0.0329, 0.0634]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0435, 0.3150, 0.1243, 0.3934, 0.0629, 0.0609]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0265, 0.2991, 0.0690, 0.4154, 0.0578, 0.1322]], device='cuda:0')
# Done counter: 158
# Number of steps: 54
# tou no hikari
# Boltzmann probabilities: tensor([[0.2982, 0.1520, 0.0607, 0.3636, 0.0346, 0.0907]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1453, 0.2090, 0.1098, 0.4409, 0.0308, 0.0642]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0370, 0.3147, 0.1025, 0.4442, 0.0506, 0.0510]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0816, 0.2237, 0.1201, 0.4566, 0.0525, 0.0655]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0403, 0.3447, 0.0904, 0.4279, 0.0471, 0.0496]], device='cuda:0')
# Done counter: 159
# Number of steps: 54
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0831, 0.2023, 0.1129, 0.5080, 0.0319, 0.0619]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1965, 0.1661, 0.0830, 0.4542, 0.0255, 0.0746]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0102, 0.2895, 0.2259, 0.4168, 0.0266, 0.0311]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0450, 0.2165, 0.0927, 0.5663, 0.0340, 0.0456]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0184, 0.3995, 0.0654, 0.4289, 0.0375, 0.0502]], device='cuda:0')
# Done counter: 160
# Number of steps: 52
# tou no hikari
# Boltzmann probabilities: tensor([[0.1416, 0.1863, 0.1029, 0.4701, 0.0281, 0.0711]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1900, 0.1829, 0.1002, 0.4191, 0.0298, 0.0780]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1351, 0.1918, 0.1162, 0.4536, 0.0288, 0.0744]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0290, 0.2426, 0.1244, 0.4242, 0.0626, 0.1172]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.2948, 0.0651, 0.4800, 0.0489, 0.0891]], device='cuda:0')
# Done counter: 161
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.1620, 0.1875, 0.1035, 0.4461, 0.0284, 0.0726]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0425, 0.2895, 0.1127, 0.4833, 0.0268, 0.0451]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.2377, 0.1454, 0.0627, 0.4172, 0.0332, 0.1038]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1472, 0.2628, 0.1086, 0.3830, 0.0452, 0.0532]], device='cuda:0')
# Done counter: 162
# Number of steps: 42
# unmei no michi
# Boltzmann probabilities: tensor([[0.2215, 0.1584, 0.0673, 0.4396, 0.0291, 0.0841]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1358, 0.1869, 0.1062, 0.4721, 0.0277, 0.0712]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0322, 0.2938, 0.1218, 0.4870, 0.0218, 0.0434]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1324, 0.2737, 0.1017, 0.3888, 0.0523, 0.0510]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0035, 0.1808, 0.2169, 0.4162, 0.0846, 0.0980]], device='cuda:0')
# Done counter: 163
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.1672, 0.1970, 0.1039, 0.4190, 0.0366, 0.0763]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1061, 0.2008, 0.1070, 0.4831, 0.0351, 0.0679]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.1532, 0.1817, 0.0981, 0.4711, 0.0261, 0.0699]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1240, 0.3094, 0.0807, 0.3988, 0.0402, 0.0470]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0041, 0.1286, 0.1201, 0.5058, 0.0813, 0.1601]], device='cuda:0')
# Done counter: 164
# Number of steps: 46
# tou no hikari
# Boltzmann probabilities: tensor([[0.1749, 0.1637, 0.0869, 0.4677, 0.0270, 0.0798]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0092, 0.2647, 0.0125, 0.4721, 0.0777, 0.1638]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1132, 0.2036, 0.1140, 0.4782, 0.0273, 0.0637]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1215, 0.2253, 0.0952, 0.4540, 0.0403, 0.0636]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0435, 0.3196, 0.0949, 0.4239, 0.0571, 0.0610]], device='cuda:0')
# Done counter: 165
# Number of steps: 56
# tou no hikari
# Boltzmann probabilities: tensor([[0.1685, 0.1836, 0.0942, 0.4489, 0.0306, 0.0742]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0868, 0.1964, 0.1359, 0.4730, 0.0330, 0.0748]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1617, 0.1838, 0.0951, 0.4636, 0.0268, 0.0690]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1312, 0.1814, 0.1053, 0.4839, 0.0264, 0.0719]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0087, 0.3320, 0.0507, 0.4568, 0.0590, 0.0928]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0014, 0.4178, 0.0036, 0.4227, 0.0573, 0.0973]], device='cuda:0')
# Done counter: 166
# Number of steps: 74
# Boltzmann probabilities: tensor([[0.0562, 0.1983, 0.1069, 0.5609, 0.0325, 0.0452]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0581, 0.2185, 0.1416, 0.4718, 0.0346, 0.0755]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0272, 0.3783, 0.1116, 0.4278, 0.0226, 0.0324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2246, 0.1780, 0.0703, 0.4143, 0.0348, 0.0779]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0060, 0.1127, 0.1683, 0.5960, 0.0487, 0.0683]], device='cuda:0')
# Done counter: 167
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.1888, 0.1652, 0.0964, 0.4409, 0.0253, 0.0834]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1935, 0.1524, 0.0512, 0.4904, 0.0323, 0.0802]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0855, 0.2266, 0.1278, 0.4451, 0.0517, 0.0634]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0013, 0.2372, 0.5196, 0.0378, 0.1994, 0.0047]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0181, 0.2577, 0.0473, 0.4307, 0.0680, 0.1782]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0010, 0.0376, 0.0557, 0.1973, 0.4914, 0.2169]], device='cuda:0')
# Done counter: 168
# Number of steps: 68
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0377, 0.2992, 0.1024, 0.4567, 0.0620, 0.0419]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0805, 0.2097, 0.1313, 0.4842, 0.0302, 0.0642]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0939, 0.1893, 0.1103, 0.5137, 0.0276, 0.0652]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0533, 0.2189, 0.1144, 0.4728, 0.0514, 0.0892]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0016, 0.4232, 0.0081, 0.4688, 0.0555, 0.0429]], device='cuda:0')
# Done counter: 169
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.1314, 0.1872, 0.1020, 0.4916, 0.0243, 0.0636]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1483, 0.1667, 0.0824, 0.5063, 0.0245, 0.0718]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0750, 0.2121, 0.1604, 0.4468, 0.0345, 0.0711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0009, 0.2415, 0.5465, 0.1174, 0.0816, 0.0121]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0599, 0.2190, 0.1358, 0.4755, 0.0444, 0.0655]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0011, 0.4136, 0.0033, 0.4605, 0.0574, 0.0641]], device='cuda:0')
# Done counter: 170
# Number of steps: 68
# tou no hikari
# Boltzmann probabilities: tensor([[0.1194, 0.1735, 0.1138, 0.4991, 0.0214, 0.0728]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1811, 0.1671, 0.1012, 0.4516, 0.0216, 0.0774]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1959, 0.1817, 0.0900, 0.4140, 0.0346, 0.0838]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0830, 0.2449, 0.1089, 0.4549, 0.0592, 0.0491]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0035, 0.1503, 0.1437, 0.5035, 0.0790, 0.1201]], device='cuda:0')
# Done counter: 171
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0006, 0.2447, 0.3383, 0.3892, 0.0252, 0.0020]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0992, 0.1886, 0.1085, 0.5078, 0.0306, 0.0654]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1790, 0.1613, 0.0925, 0.4565, 0.0257, 0.0849]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0890, 0.2031, 0.1129, 0.4923, 0.0361, 0.0666]], device='cuda:0')
# Done counter: 172
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.1593, 0.1620, 0.0934, 0.4818, 0.0221, 0.0814]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1284, 0.1756, 0.1047, 0.4850, 0.0318, 0.0744]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.1755, 0.1692, 0.0899, 0.4709, 0.0232, 0.0713]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1245, 0.2031, 0.0889, 0.4774, 0.0377, 0.0684]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0043, 0.1593, 0.1831, 0.4314, 0.0873, 0.1347]], device='cuda:0')
# Done counter: 173
# Number of steps: 48
# slime-san onegai
# Boltzmann probabilities: tensor([[0.1433, 0.2003, 0.1077, 0.4541, 0.0279, 0.0668]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1843, 0.1626, 0.0706, 0.4638, 0.0309, 0.0878]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0684, 0.2195, 0.1230, 0.4809, 0.0438, 0.0645]], device='cuda:0')
# senrigan
# Boltzmann probabilities: tensor([[0.0789, 0.2669, 0.1453, 0.3947, 0.0542, 0.0600]], device='cuda:0')
# Done counter: 174
# Number of steps: 44
# senrigan
# Boltzmann probabilities: tensor([[0.0017, 0.4326, 0.0545, 0.5014, 0.0071, 0.0027]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2473, 0.1428, 0.0620, 0.3952, 0.0378, 0.1150]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1060, 0.1925, 0.1203, 0.4761, 0.0307, 0.0744]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1003, 0.2816, 0.0806, 0.4044, 0.0662, 0.0668]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0669, 0.3174, 0.1102, 0.3962, 0.0633, 0.0461]], device='cuda:0')
# Done counter: 175
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0153, 0.1655, 0.1035, 0.6834, 0.0143, 0.0181]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1453, 0.1957, 0.1090, 0.4679, 0.0194, 0.0626]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1620, 0.1685, 0.0961, 0.4683, 0.0269, 0.0783]], device='cuda:0')
# unmei no michi
# Boltzmann probabilities: tensor([[0.0942, 0.1893, 0.1200, 0.4917, 0.0306, 0.0743]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0055, 0.4788, 0.0355, 0.3873, 0.0541, 0.0388]], device='cuda:0')
# Done counter: 176
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.2162, 0.1464, 0.0692, 0.4375, 0.0311, 0.0996]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2106, 0.1603, 0.0802, 0.4190, 0.0330, 0.0968]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1628, 0.1831, 0.0996, 0.4541, 0.0276, 0.0728]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0418, 0.3082, 0.2375, 0.2992, 0.0793, 0.0340]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1271, 0.1941, 0.1085, 0.4648, 0.0331, 0.0725]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0084, 0.3746, 0.0555, 0.4611, 0.0517, 0.0488]], device='cuda:0')
# Done counter: 177
# Number of steps: 66
# Boltzmann probabilities: tensor([[0.0709, 0.2070, 0.1220, 0.5189, 0.0231, 0.0580]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0023, 0.3165, 0.0617, 0.6072, 0.0072, 0.0050]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1219, 0.1788, 0.1051, 0.4793, 0.0329, 0.0821]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0510, 0.2951, 0.0818, 0.4662, 0.0550, 0.0510]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0036, 0.1446, 0.1294, 0.5101, 0.0816, 0.1307]], device='cuda:0')
# Done counter: 178
# Number of steps: 46
# unmei no michi
# Boltzmann probabilities: tensor([[0.0265, 0.1905, 0.1050, 0.6480, 0.0130, 0.0171]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1415, 0.1693, 0.0917, 0.4844, 0.0275, 0.0856]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1410, 0.1866, 0.1015, 0.4649, 0.0316, 0.0744]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0757, 0.2324, 0.1469, 0.4499, 0.0549, 0.0403]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0031, 0.1447, 0.1279, 0.5339, 0.0765, 0.1138]], device='cuda:0')
# Done counter: 179
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.1742, 0.1730, 0.0868, 0.4713, 0.0232, 0.0715]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.0747, 0.2130, 0.1377, 0.4650, 0.0425, 0.0672]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1357, 0.1737, 0.1002, 0.4977, 0.0228, 0.0700]], device='cuda:0')
# tou no hikari
# Boltzmann probabilities: tensor([[0.1318, 0.1817, 0.0957, 0.4951, 0.0275, 0.0683]], device='cuda:0')
# slime-san onegai
# Boltzmann probabilities: tensor([[0.0076, 0.4054, 0.0689, 0.3971, 0.0918, 0.0292]], device='cuda:0')
# Done counter: 180
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.1053, 0.2205, 0.1205, 0.4694, 0.0300, 0.0543]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0965, 0.1825, 0.1146, 0.5031, 0.0353, 0.0680]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0843, 0.2229, 0.1321, 0.4623, 0.0300, 0.0684]], device='cuda:0')
# average number of steps: 55
# max: 96
# min: 42
