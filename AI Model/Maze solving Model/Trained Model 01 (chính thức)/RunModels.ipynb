# %%
# Khai báo các thư viện cần thiết
import torch
import numpy as np
import random
import os
import pickle
from collections import deque
import torch.nn as nn
import torch.nn.functional as F

# %%
# Khai báo các hằng số sử dụng
class Action:
    UP = 0
    DOWN = 1
    LEFT = 2
    RIGHT = 3
class Maze:
    WALL = -1
    UNEXPLORED = 0
    PATH = 1
    GOAL = 2
    AGENT_POSITION = 3
class Buff:
    NONE = 0
    SENRIGAN = 1
    TOU_NO_HIKARI = 2
    SLIME_SAN_ONEGAI = 3
    UNMEI_NO_MICHI = 4
    SLIME_STEP = 150
    TOU_NO_HIKARI_OBS = 10
    UNMEI_NO_MICHI_PATH = 1
class Debuff:
    NONE = 0
    WAAMU_HOURU = 1
    SHIN_NO_MEIRO = 2

# %%
# Mạng nơron

class MetaModelNet(nn.Module):
    """
    Mạng nơron cho mô hình MetaModelNet.
    """
    def __init__(self, num_classes):
        super(MetaModelNet, self).__init__()
    
        # Tầng FC cho position
        self.fc_position = nn.Linear(2, 32)
        # Dropout trước tầng FC cuối cùng
        self.dropout = nn.Dropout(0.5)
        # Tầng đầu ra
        self.fc = nn.Linear(32, num_classes)

    def forward(self, position):
        return self.fc(self.dropout(F.relu(self.fc_position(position))))

# Mạng Nơ ron 
class MazeNet(nn.Module):
    def __init__(self):
        super(MazeNet, self).__init__()

        # Quan sát cục bộ
        self.conv1_local = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2_local = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3_local = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4_local = nn.Conv2d(128, 256, kernel_size=3, padding=1)

        # Quan sát toàn cục
        self.conv1_global = nn.Conv2d(1, 32, kernel_size=2, stride=2, padding=0)
        self.conv2_global = nn.Conv2d(32, 64, kernel_size=2, stride=2, padding=0)

        # Xử lý vị trí
        self.fc_position = nn.Linear(2, 32)  # Vị trí hiện tại

        # Tầng Fully Connected cuối cùng
        self.fc1 = nn.LazyLinear(256)
        self.fc2 = nn.LazyLinear(128) 
        self.dropout_fc = nn.Dropout(p=0.5)  # Dropout trước tầng FC3
        self.fc3 = nn.LazyLinear(4)  # Đầu ra cho 4 hành động (lên, xuống, trái, phải)
    
    def forward(self, local_obs, global_obs, position):
        # Xử lý local_obs
        x_local = F.relu(self.conv1_local(local_obs))
        x_local = F.relu(self.conv2_local(x_local))
        x_local = F.relu(self.conv3_local(x_local))
        x_local = F.relu(self.conv4_local(x_local))
        x_local = x_local.view(x_local.size(0), -1)

        # Xử lý global_obs
        x_global = F.relu(self.conv1_global(global_obs))
        x_global = F.relu(self.conv2_global(x_global))
        x_global = x_global.view(x_global.size(0), -1)
        
        # Xử lý vị trí hiện tại
        x_position = F.relu(self.fc_position(position))
        
        # Kết hợp tất cả
        x = torch.cat((x_local, x_global, x_position), dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout_fc(x)  # Dropout trước FC3
        x = self.fc3(x)

        return x

# %%
# Môi trường Mê cung

class MazeEnv():
    # Môi trường mê cung
    # Maze: Mê cung được tạo ra ngẫu nhiên với các ô đường và tường
    # Với các ô đường được đánh dấu là 0 và các ô tường được đánh dấu là -1, ô đích được đánh dấu là 2
    # Discovered_maze: Mê cung đã được khám phá trong quá trình di chuyển của tác tử
    # Với các ô đường được đánh dấu là 0, các ô tường được đánh dấu là -5, đích được đánh dấu là 10, ô chưa được khám phá được đánh dấu là 1
    # Giá trị các ô đường giảm dần mỗi lần tác tử đi qua
    # Agent_position: Vị trí hiện tại của tác tử trong mê cung
    # Base_position: Vị trí ban đầu của tác tử trong mê cung
    # Goal_position: Vị trí đích trong mê cung
    # Buff: Biến để xác định xem tác tử có đang sử dụng buff senrigan hay không
    # Debuff: Biến để xác định xem tác tử có đang bị debuff shin no meiro hay không

    def __init__(self, maze_size, max_steps = 15, path_percent = 70):
        """
        Khởi tạo môi trường Mê cung.

        Args:
        - maze_size (int): Kích thước của mê cung (ví dụ: 50x50).
        - max_steps (int): Số bước tối đa cho mỗi tập.
        - path_percent (int): Tỷ lệ phần trăm ô đường trong mê cung (0-100).
        """
        # Đặt các thông số của môi trường
        self.maze_size = maze_size
        self.max_steps = max_steps
        self.path_percent = path_percent
        
        self.maze = np.ones((maze_size, maze_size), dtype=int) * Maze.UNEXPLORED # Tạo mê cung với tất cả ô là chưa khám phá
        self.base_position = (maze_size // 6 - 1, maze_size // 6 - 1)  # Vị trí bắt đầu của tác tử
        self.goal_position = (maze_size * 5 // 6, maze_size * 5 // 6)  # Đích cố định tại giữa khu vực đích
        self.senrigan_buff = False
        self.shin_no_meiro_debuff = False

    # Các phương thức liên quan đến tái tạo mê cung
    def reset(self, buff = Buff.NONE, debuff = Debuff.NONE):
        self.agent_position = self.base_position
        return self.regenerate_maze(buff, debuff)

    def regenerate_maze(self, buff = Buff.NONE, debuff = Debuff.NONE):
        # Kích hoạt buff
        if buff == Buff.SENRIGAN:
            self.senrigan_buff = True
        else:
            self.senrigan_buff = False
        if buff == Buff.UNMEI_NO_MICHI:
            adder = Buff.UNMEI_NO_MICHI_PATH
        else:
            adder = 0
        # Kích hoạt debuff
        if debuff == Debuff.WAAMU_HOURU:
            self.agent_position = (random.randint(self.maze_size // 3, self.maze_size), random.randint(self.maze_size // 3, self.maze_size))
        if debuff == Debuff.SHIN_NO_MEIRO:
            self.shin_no_meiro_debuff = True
        else:
            self.shin_no_meiro_debuff = False
        # Tạo mê cung mới
        self.generate_maze(adder)
        self.create_discovered_maze()

        # Kích hoạt buff
        if buff == Buff.SLIME_SAN_ONEGAI:
            self.bfs(self.agent_position, Buff.SLIME_STEP)
        if buff == Buff.TOU_NO_HIKARI:
            local_obs_size = Buff.TOU_NO_HIKARI_OBS
        else:
            local_obs_size = 3
        self.discover_maze(local_obs_size)

        return_discovered_maze = self.discovered_maze.copy()
        return self.get_observation(), return_discovered_maze, self.agent_position

    def generate_maze(self, adder = 0):
        if self.agent_position[0] >= self.maze_size * 2 // 3 and self.agent_position[1] >= self.maze_size * 2 // 3:
            number_of_path = 1 + adder
        else:
            number_of_path = 2 + adder

        total_cells = self.maze_size * self.maze_size
        num_paths = int(total_cells * self.path_percent / 100)
        num_walls = total_cells - num_paths
        maze_values = [Maze.PATH] * num_paths + [Maze.WALL] * num_walls

        while True:  # Sử dụng vòng lặp để tạo lại mê cung nếu không hợp lệ
            random.shuffle(maze_values)  # Xáo trộn các giá trị
            
            # Điền vào mê cung
            self.maze = np.array(maze_values).reshape(self.maze_size, self.maze_size)
            
            # Đặt điểm bắt đầu và đích
            self.maze[self.agent_position] = Maze.PATH # Đặt vị trí tác tử là đường 
            self.maze[self.goal_position] = Maze.GOAL # Đặt vị trí đích

            # Kiểm tra tính hợp lệ
            if self.validate_maze(number_of_path):
                break  # Nếu mê cung hợp lệ, thoát vòng lặp

    def validate_maze(self, number_of_path = 0):
        d = 0
        temp_maze = self.maze.copy()  # Tạo bản sao của mê cung
        for _ in range(number_of_path):
            path = self.shortest_path(temp_maze)
            if path is None:  # Nếu không tìm thấy đường đi
                break
            d += 1  # Tăng số lượng đường đi hợp lệ
            for x, y in path:
                temp_maze[x, y] = Maze.WALL 
                # Đánh dấu các ô đã đi qua là tường
            temp_maze[self.agent_position] = Maze.PATH  # Đặt lại vị trí tác tử là đường
            temp_maze[self.goal_position] = Maze.GOAL  # Đặt lại vị trí đích là đường

        if self.shin_no_meiro_debuff:
            return d==0
        if d == number_of_path:
            return True
        else:
            return False
        
    def shortest_path(self, maze):
        # Hàng đợi để BFS
        queue = deque([(self.agent_position, [self.agent_position])])  # Lưu trữ (vị trí hiện tại, đường đi)
        visited = set()  # Tập hợp các điểm đã thăm
        visited.add(self.agent_position)
        
        while queue:
            current, path = queue.popleft()

            # Kiểm tra nếu đã đến điểm end
            if current == self.goal_position:
                return path  # Trả về đường đi ngắn nhất
            
            # Lấy các điểm lân cận
            for neighbor in self.get_neighbors(current[0], current[1]):
                if neighbor not in visited and maze[neighbor] != Maze.WALL: 
                    visited.add(neighbor)
                    queue.append((neighbor, path + [neighbor]))
        
        return None  # Không tìm thấy đường đi

    def get_neighbors(self, x, y):
        """
        Lấy danh sách các ô lân cận.
        """
        neighbors = []
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nx, ny = x + dx, y + dy
            if 0 <= nx < self.maze_size and 0 <= ny < self.maze_size:
                neighbors.append((nx, ny))
        return neighbors
    
    # Các phương thức liên quan đến mê cung được khám phá
    def create_discovered_maze(self):
        self.discovered_maze = np.zeros((self.maze_size + 10, self.maze_size + 10), dtype=int)  # Tạo mê cung đã khám phá
        self.discovered_maze.fill(Maze.UNEXPLORED)  # Đánh dấu tất cả ô là chưa khám phá (1)
        self.discovered_maze[0 : 5, :] = 5 * Maze.WALL
        self.discovered_maze[:, 0 : 5] = 5 * Maze.WALL
        self.discovered_maze[self.maze_size + 5 : self.maze_size + 10, :] = 5 * Maze.WALL
        self.discovered_maze[:, self.maze_size + 5 : self.maze_size + 10] = 5 * Maze.WALL
        self.discovered_maze[self.goal_position[0] + 5, self.goal_position[1] + 5] = 10  # Đích được đánh dấu là 10
        
    def discover_maze(self, local_obs_size = 3):
        x, y = self.agent_position
        if self.senrigan_buff:
            half_size = max(5, local_obs_size)  
            self.local_obs_size = 5
        else:
            half_size = max(3, local_obs_size)  
            self.local_obs_size = 3

        # Xác định giới hạn của vùng quan sát trong mê cung
        min_x = max(0, x - half_size)
        max_x = min(self.maze_size, x + half_size + 1)
        min_y = max(0, y - half_size)
        max_y = min(self.maze_size, y + half_size + 1)

        # Điền dữ liệu từ mê cung vào vùng khám phá
        for x in range(min_x, max_x):
            for y in range(min_y, max_y):
                if self.discovered_maze[x + 5, y + 5] == Maze.UNEXPLORED:
                    if self.maze[x, y] == Maze.PATH:
                        self.discovered_maze[x + 5, y + 5] = 2 * Maze.PATH
                    else:
                        self.discovered_maze[x + 5, y + 5] = 5 * self.maze[x, y]
        
    # Phương thức chính để thực hiện hành động trong môi trường
    def step(self, action, take_action):
        """
        Thực hiện hành động và cập nhật trạng thái của môi trường.
    
        Args:
        - action (int): Hành động 
    
        Returns:
        - local_obs (np.array): Quan sát hiện tại của tác tử
        - global_obs (np.array): Mê cung đã khám phá
        - reward (float): Phần thưởng
        - done (bool): Trạng thái kết thúc
        """
        # Lưu lại trạng thái nếu không thực hiện hành động
        if not take_action:
            saved_position = self.agent_position
            saved_discovered_maze = self.discovered_maze.copy()

        # Lấy vị trí hiện tại của tác tử
        x, y = self.agent_position
    
        # Xác định vị trí mới dựa trên hành động
        if action == Action.UP:  # Lên
            new_x, new_y = x - 1, y
        elif action == Action.DOWN:  # Xuống
            new_x, new_y = x + 1, y
        elif action == Action.LEFT:  # Trái
            new_x, new_y = x, y - 1
        elif action == Action.RIGHT:  # Phải
            new_x, new_y = x, y + 1
    
        # Khởi tạo biến phần thưởng
        reward = 0
        done = False
        
        # Cập nhật vị trí tác tử
        if self.valid_check((new_x, new_y)) and self.discovered_maze[new_x + 5, new_y + 5] != 5 * Maze.WALL:  # Nếu vị trí mới hợp lệ và không phải là tường
            # Nếu vị trí mới hợp lệ, cập nhật vị trí tác tử
            self.agent_position = (new_x, new_y)
            self.discover_maze()
        # Tính toán phần thưởng
        reward, done = self.calculate_reward((x, y), (new_x, new_y))
        
        # Tính giá trị discovered maze
        if self.discovered_maze[new_x + 5, new_y + 5] == 2 * Maze.PATH:  # Nếu ô chưa được khám phá
            self.discovered_maze[new_x + 5, new_y + 5] = -1  
        else:
            # Giảm giá trị ô đã khám phá
            self.discovered_maze[new_x + 5, new_y + 5] -= 1
        
        # Tạo quan sát hiện tại
        local_obs = self.get_observation()
 
        #Tạo quan sát toàn mê cung
        global_obs = self.discovered_maze.copy()
        
        # Tạo kết quả trả về vị trí tác tử
        return_agent_position = self.agent_position

        # Trả lại các giá trị đã lưu nếu không thực hiện hành động
        if not take_action:
            self.agent_position = saved_position
            self.discovered_maze = saved_discovered_maze.copy()
        return local_obs, global_obs, return_agent_position, reward, done

    def calculate_reward(self, p1, p2):
        done = False
        reward = 0
        if self.discovered_maze[p2[0] + 5, p2[1] + 5] == 5 * Maze.WALL:
            reward -= 3 * self.maze_size  # Phạt lớn khi va chạm với tường
        elif p2 == self.goal_position:
            reward += 5 * self.maze_size  # Thưởng lớn khi đến đích
            done = True
        else:
            # Tính khoảng cách Manhattan từ vị trí hiện tại tới đích
            current_distance = abs(p2[0] - self.goal_position[0]) + abs(p2[1] - self.goal_position[1])
            
            # Tính khoảng cách trước đó
            previous_distance = abs(p1[0] - self.goal_position[0]) + abs(p1[1] - self.goal_position[1])

            # Tăng thưởng nếu đến gần đích hơn
            if self.discovered_maze[p2[0] + 5, p2[1] + 5] == 2 * Maze.PATH:  # Nếu ô chưa được khám phá
                if current_distance < previous_distance:
                    reward += 3 * self.maze_size // current_distance  # Thưởng khi di chuyển đến gần đích hơn
                else:
                    reward -= self.maze_size # Phạt nếu tác tử đi xa hơn
            else:
                # Phạt khi đi vào ô đã khám phá
                reward += self.discovered_maze[p2[0] + 5, p2[1] + 5] * self.maze_size // current_distance + self.discovered_maze[p2[0] + 5, p2[1] + 5] * self.maze_size
        return reward, done
    
    # Tính long term q values
    def calculate_long_term_q(self, step_remaining, lt_gamma, device):
        """
        Tính toán giá trị Q dài hạn cho tác tử.
    
        Args:
        - step_remaining (int): Số bước còn lại để di chuyển.
        - lt_gamma (float): Hệ số giảm giá cho giá trị Q dài hạn.
    
        Returns:
        - long_term_q (float): Giá trị Q dài hạn.
        """
        # Tính số bước để đi đến các ô xung quanh
        step_needed = np.ones((self.maze_size, self.maze_size), dtype=int) * self.max_steps
        step_needed[self.agent_position] = 0
        # Tính giá trị Q dài hạn của từng ô
        lt_q = np.ones((self.maze_size, self.maze_size), dtype=float) * -100
        lt_q[self.agent_position] = 0
        # Hướng di chuyển ban đầu đến từng ô
        start_direction = np.ones((self.maze_size, self.maze_size), dtype=int) * -1
        # Tính giá trị Q dài hạn của từng hướng
        lt_q_direction_values = np.ones(4, dtype=float) * -100
        for i in range(step_remaining):
            for j in range(self.maze_size):
                for k in range(self.maze_size):
                    if step_needed[j, k] > i and self.discovered_maze[j + 5, k + 5] != 5 * Maze.WALL and self.discovered_maze[j + 5, k + 5] != Maze.UNEXPLORED:
                        neighbors = self.get_neighbors(j, k)
                        for nx, ny in neighbors:
                            if step_needed[nx, ny] == i and self.discovered_maze[nx + 5, ny + 5] != 5 * Maze.WALL and self.discovered_maze[nx + 5, ny + 5] != Maze.UNEXPLORED:
                                step_needed[j, k] = i + 1
                                temp_q = lt_q[nx, ny] + self.calculate_reward((nx, ny), (j, k))[0] * (lt_gamma ** (i + 1 - step_remaining))
                                if temp_q > lt_q[j, k]:
                                    lt_q[j, k] = temp_q
                                    start_direction[j, k] = start_direction[nx, ny]
                                    if start_direction[j, k] == -1:
                                        direction = (j - nx, k - ny)
                                        if direction == (-1, 0):
                                            start_direction[j, k] = Action.UP
                                        elif direction == (1, 0):
                                            start_direction[j, k] = Action.DOWN
                                        elif direction == (0, -1):
                                            start_direction[j, k] = Action.LEFT
                                        elif direction == (0, 1):
                                            start_direction[j, k] = Action.RIGHT
                                    if temp_q > lt_q_direction_values[start_direction[j, k]]:
                                        lt_q_direction_values[start_direction[j, k]] = temp_q
        return torch.Tensor(lt_q_direction_values).to(device)
    
    # Xuất dữ liệu mê cung
    def render(self):
        render_maze = np.zeros((self.maze_size, self.maze_size), dtype = int) 
        for i in range(self.maze_size):
            for j in range(self.maze_size):
                if self.maze[i][j] == Maze.WALL:
                    render_maze[i][j] = 1
                    continue
                if self.maze[i][j] == Maze.GOAL:
                    render_maze[i][j] = 10
                    continue
        print(render_maze)
    
    # Phương thức để lấy quan sát hiện tại của tác tử
    def get_observation(self):
        x, y = self.agent_position
        observation = np.zeros((2 * self.local_obs_size + 1, 2*self.local_obs_size + 1), dtype = int)
        observation[:, :] = self.discovered_maze[x + 5 - self.local_obs_size: x + 6 + self.local_obs_size, y + 5 - self.local_obs_size : y + 6 + self.local_obs_size]
        return observation

    def bfs(self, position, step):
        """
        Thuật toán BFS (Breadth-First Search)
    
        Args:
        - position: Đỉnh bắt đầu tìm kiếm.
        - step: số bược di chuyển
    
        """
        # Tập các đỉnh đã duyệt
        visited = set()
        visited_counter = 0
    
        # Hàng đợi (FIFO) để quản lý các đỉnh
        queue = deque([position])
    
        # Bắt đầu duyệt đồ thị
        while queue:
            # Lấy một đỉnh từ hàng đợi
            current = queue.popleft()
            x,y = current
            
            # Kiểm tra nếu đỉnh chưa được duyệt
            if current not in visited:
                visited.add(current)
                visited_counter += 1
                if self.discovered_maze[x + 5, y + 5] == Maze.UNEXPLORED:
                    if self.maze[x, y] == Maze.PATH:
                        self.discovered_maze[x + 5, y + 5] = 2 * Maze.PATH
                    else:
                        self.discovered_maze[5 + x, 5 + y] = 5 * self.maze[x, y]
                    
                # Nếu đã duyệt đủ số bước, dừng lại
                if visited_counter >= step:
                    break
                neighbors = self.get_neighbors(x, y)
                for nx, ny in neighbors:
                    if self.maze[nx, ny] != Maze.WALL and (nx, ny) not in visited:  # Chỉ đi qua đường
                        queue.append((nx, ny))
    
    # Phương thức để kiểm tra tính hợp lệ của một vị trí
    def valid_check(self, p1):
        if 0 <= p1[0] < self.maze_size and 0 <= p1[1] < self.maze_size and self.maze[p1] != Maze.WALL:
            return True
        return False

# %%
# Tải model
def load_model(model_path, device = "cuda"):
    # Load the model
    model = torch.load(model_path, map_location=device, weights_only=False)
    model.eval()  # Chuyển model về chế độ đánh giá (evaluation mode)
    return model

# %%
# Tải meta-model và các model liên quan
while True:
    meta_model_path = input("Enter the meta-model name: ")
    if os.path.exists(meta_model_path + "/meta_model.pth"):
        break
    else:
        print("Meta-model not found. Please enter a valid name.")

meta_model = load_model(meta_model_path + "/meta_model.pth")

with open(meta_model_path + "/models_info.pkl", "rb") as f:
    models_info = pickle.load(f)

model_counter = 0
models = []
for model_info in models_info:
    print(model_info)
    model = load_model(model_info['model_path'])
    buff = model_info['buff']
    lt_gamma = model_info['lt_gamma']
    models.append((model, buff, lt_gamma))
    model_counter += 1
    print(f"Mode path: {model_info['model_path']}, Buff: {buff}")
print(f"Loaded {model_counter} models")
# Out:
# {'model_path': 'model01/model.pth', 'lt_gamma': 1.25, 'buff': 0}
# Mode path: model01/model.pth, Buff: 0
# {'model_path': 'model02/model.pth', 'lt_gamma': 1.25, 'buff': 1}
# Mode path: model02/model.pth, Buff: 1
# {'model_path': 'model03/model.pth', 'lt_gamma': 1.25, 'buff': 2}
# Mode path: model03/model.pth, Buff: 2
# {'model_path': 'model04/model.pth', 'lt_gamma': 1.25, 'buff': 3}
# Mode path: model04/model.pth, Buff: 3
# {'model_path': 'model05/model.pth', 'lt_gamma': 1.25, 'buff': 4}
# Mode path: model05/model.pth, Buff: 4
# Loaded 5 models

# %%
# Khởi tạo các siêu tham số
maze_size = 30
max_steps = 15
path_percent = 70
num_actions = 4

max_episodes = 10000
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Chọn model phù hợp
def select_model(position):
    with torch.no_grad():
        position = torch.tensor(position, dtype=torch.float32).unsqueeze(0).to(device)
        # Dự đoán hành động từ mô hình meta
        action_probs = meta_model(position)

    # Tính xác suất Boltzmann cho mỗi mô hình
    boltzmann_probs = torch.softmax(action_probs * 5, dim = 1)
    print(f"Boltzmann probabilities: {boltzmann_probs}")
    
    # Chọn mô hình dựa trên xác suất Boltzmann
    model_index = torch.multinomial(boltzmann_probs, num_samples=1).item()
    model, buff, lt_gamma = models[model_index]
    return model, buff, lt_gamma

# %%
# Chọn hành động
def select_action(env, policy_net, position, local_obs, global_obs, step_remaining, lt_gamma, device):
    """
    Chọn hành động dựa trên chiến lược Boltzmann Exploration.

    Args:
    - policy_net (nn.Module): Mạng chính để dự đoán giá trị Q(s, a).
    - local_obs (np.array): Quan sát cục bộ (ví dụ: 11x11).
    - global_obs (np.array): Quan sát toàn bộ mê cung (ví dụ: 50x50).
    - position (list or np.array): Vị trí hiện tại của tác tử (dx, dy).
    - device (torch.device): Thiết bị thực thi (CPU hoặc GPU).

    Returns:
    - action (int): Hành động được chọn (0, 1, 2, 3).
    """
    p1 = (position[0] - 1, position[1])
    p2 = (position[0] + 1, position[1])
    p3 = (position[0], position[1] - 1)
    p4 = (position[0], position[1] + 1)

    # Loại bỏ các hành động không hợp lệ (nếu cần)
    valid_actions = []
    if env.valid_check(p1): valid_actions.append(Action.UP)  # Lên
    if env.valid_check(p2): valid_actions.append(Action.DOWN)  # Xuống
    if env.valid_check(p3): valid_actions.append(Action.LEFT)  # Trái
    if env.valid_check(p4): valid_actions.append(Action.RIGHT)  # Phải

    # Chuyển đổi các quan sát thành Tensor để đưa vào mạng
    local_obs_tensor = torch.tensor(local_obs, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
    global_obs_tensor = torch.tensor(global_obs, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
    position_tensor = torch.tensor(position, dtype=torch.float32).unsqueeze(0).to(device)

    # Dự đoán giá trị Q(s, a) cho tất cả các hành động
    st_q_values = policy_net(local_obs_tensor, global_obs_tensor, position_tensor)  # Đầu ra: (1, num_actions)
    lt_q_values = env.calculate_long_term_q(step_remaining, lt_gamma, device)  # Tính giá trị Q dài hạn cho các hành động
    
    q_values = st_q_values + lt_q_values  # Kết hợp giá trị Q từ cả hai mạng
    valid_q_values = q_values.squeeze(0)[valid_actions]  # Lấy giá trị Q cho các hành động hợp lệ
    
    # Lấy giá trị Q lớn nhất trong các hành động hợp lệ
    action = valid_actions[valid_q_values.argmax().item()]  # Chọn hành động có giá trị Q lớn nhất
    
    return action

# %%
# Vòng lặp chạy chương trình
counter = 0
step_min = 1000
step_max = 0
done_count = 0
env = MazeEnv(maze_size=maze_size, max_steps=max_steps, path_percent=path_percent)
env.reset()

for episode in range(max_episodes):
    if counter % env.max_steps == 0:
        # Chọn model phù hợp
        model, buff, lt_gamma = select_model(position)

        # Khởi tạo trạng thái môi trường
        local_obs, global_obs, position = env.regenerate_maze(buff)
    counter += 1

    # Chọn hành động
    action = select_action(env, model, position, local_obs, global_obs, env.max_steps - counter % env.max_steps, lt_gamma, device)

    # Thực hiện hành động trong môi trường
    local_obs, global_obs, position, _, done = env.step(action, True)
    
    # reset môi trường nếu đạt được mục tiêu
    if done:
        done_count += 1
        print(f"Done counter: {done_count}")
        print(f"Number of steps: {counter}")
        if counter > step_max:
            step_max = counter
        if counter < step_min: 
            step_min = counter
        counter = 0
        local_obs, global_obs, position = env.reset(buff)

print(f"average number of steps: {(max_episodes - counter) // done_count}")
print(f"max: {step_max}")
print(f"min: {step_min}")
# Out:
# Boltzmann probabilities: tensor([[0.0368, 0.1378, 0.1540, 0.0397, 0.6317]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0203, 0.1221, 0.3693, 0.1292, 0.3592]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0142, 0.0750, 0.4623, 0.0770, 0.3716]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0136, 0.0681, 0.4266, 0.0695, 0.4220]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1857, 0.2557, 0.1836, 0.0557, 0.3193]], device='cuda:0')
# Done counter: 1
# Number of steps: 66
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0202, 0.1132, 0.3337, 0.1226, 0.4103]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0211, 0.1239, 0.2308, 0.0884, 0.5359]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0167, 0.0720, 0.1994, 0.0573, 0.6546]], device='cuda:0')
# Done counter: 2
# Number of steps: 58
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 3
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0208, 0.1210, 0.3395, 0.1302, 0.3884]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0157, 0.0662, 0.2402, 0.0763, 0.6017]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 4
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0223, 0.1313, 0.2732, 0.1331, 0.4401]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0160, 0.0727, 0.2351, 0.0800, 0.5962]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1032, 0.1793, 0.1803, 0.0604, 0.4768]], device='cuda:0')
# Done counter: 5
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2124, 0.0626, 0.6440]], device='cuda:0')
# Done counter: 6
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.0901, 0.1729, 0.0452, 0.6714]], device='cuda:0')
# Done counter: 7
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 8
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2124, 0.0626, 0.6440]], device='cuda:0')
# Done counter: 9
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0235, 0.1556, 0.2067, 0.0754, 0.5389]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0164, 0.0720, 0.2489, 0.0826, 0.5801]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1030, 0.1673, 0.1982, 0.0640, 0.4674]], device='cuda:0')
# Done counter: 10
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0292, 0.2226, 0.2442, 0.1310, 0.3730]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1085, 0.2486, 0.0998, 0.5232]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0161, 0.0620, 0.2400, 0.0684, 0.6135]], device='cuda:0')
# Done counter: 11
# Number of steps: 58
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0212, 0.1353, 0.1868, 0.0590, 0.5978]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0227, 0.0826, 0.1927, 0.0541, 0.6479]], device='cuda:0')
# Done counter: 12
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0157, 0.0678, 0.3720, 0.0683, 0.4763]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1612, 0.2158, 0.1734, 0.0591, 0.3905]], device='cuda:0')
# Done counter: 13
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0215, 0.1173, 0.2828, 0.1305, 0.4478]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0152, 0.0670, 0.2278, 0.0737, 0.6163]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 14
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0214, 0.1291, 0.3446, 0.1381, 0.3668]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0172, 0.0782, 0.2573, 0.0892, 0.5580]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1042, 0.1706, 0.1862, 0.0629, 0.4760]], device='cuda:0')
# Done counter: 15
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0679, 0.3507, 0.0737, 0.4930]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 16
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1656, 0.2433, 0.1480, 0.0501, 0.3930]], device='cuda:0')
# Done counter: 17
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 18
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0246, 0.1679, 0.2107, 0.0807, 0.5161]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0173, 0.0875, 0.1798, 0.0492, 0.6662]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1214, 0.2490, 0.1345, 0.0403, 0.4548]], device='cuda:0')
# Done counter: 19
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0187, 0.1079, 0.3887, 0.1136, 0.3711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0162, 0.0672, 0.3397, 0.0686, 0.5084]], device='cuda:0')
# Done counter: 20
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0220, 0.1029, 0.1583, 0.0394, 0.6773]], device='cuda:0')
# Done counter: 21
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 22
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0235, 0.1556, 0.2067, 0.0754, 0.5389]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0220, 0.1029, 0.1583, 0.0394, 0.6773]], device='cuda:0')
# Done counter: 23
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0193, 0.1151, 0.3946, 0.1205, 0.3506]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0146, 0.0803, 0.4710, 0.0819, 0.3522]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0992, 0.1732, 0.2190, 0.0643, 0.4443]], device='cuda:0')
# Done counter: 24
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0157, 0.0684, 0.2679, 0.0776, 0.5704]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2382, 0.2673, 0.1333, 0.0480, 0.3132]], device='cuda:0')
# Done counter: 25
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0179, 0.1044, 0.1710, 0.0467, 0.6599]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 26
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0153, 0.0734, 0.3605, 0.0792, 0.4716]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2373, 0.2635, 0.1440, 0.0511, 0.3042]], device='cuda:0')
# Done counter: 27
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0157, 0.0662, 0.2402, 0.0763, 0.6017]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2382, 0.2673, 0.1333, 0.0480, 0.3132]], device='cuda:0')
# Done counter: 28
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0162, 0.0672, 0.3397, 0.0686, 0.5084]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1032, 0.1793, 0.1803, 0.0604, 0.4768]], device='cuda:0')
# Done counter: 29
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0235, 0.1556, 0.2067, 0.0754, 0.5389]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 30
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0171, 0.0914, 0.3869, 0.0969, 0.4078]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0626, 0.1281, 0.2156, 0.0663, 0.5274]], device='cuda:0')
# Done counter: 31
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0246, 0.1679, 0.2107, 0.0807, 0.5161]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0160, 0.0766, 0.1951, 0.0560, 0.6562]], device='cuda:0')
# Done counter: 32
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0185, 0.0919, 0.2555, 0.1009, 0.5332]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0373, 0.0961, 0.2084, 0.0640, 0.5943]], device='cuda:0')
# Done counter: 33
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 34
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0187, 0.1079, 0.3887, 0.1136, 0.3711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3227, 0.3024, 0.1119, 0.0411, 0.2219]], device='cuda:0')
# Done counter: 35
# Number of steps: 60
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Done counter: 36
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0622, 0.2202, 0.0678, 0.6350]], device='cuda:0')
# Done counter: 37
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.1137, 0.2650, 0.1172, 0.4836]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0622, 0.2202, 0.0678, 0.6350]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3227, 0.3024, 0.1119, 0.0411, 0.2219]], device='cuda:0')
# Done counter: 38
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0258, 0.1891, 0.1930, 0.0704, 0.5216]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0188, 0.1175, 0.1565, 0.0408, 0.6663]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2382, 0.2673, 0.1333, 0.0480, 0.3132]], device='cuda:0')
# Done counter: 39
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 40
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0235, 0.1556, 0.2067, 0.0754, 0.5389]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.0901, 0.1729, 0.0452, 0.6714]], device='cuda:0')
# Done counter: 41
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 42
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0202, 0.1132, 0.3337, 0.1226, 0.4103]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0137, 0.0706, 0.4497, 0.0715, 0.3945]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1554, 0.2246, 0.1919, 0.0593, 0.3688]], device='cuda:0')
# Done counter: 43
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0667, 0.2110, 0.0635, 0.6439]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0180, 0.0824, 0.1840, 0.0504, 0.6653]], device='cuda:0')
# Done counter: 44
# Number of steps: 58
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0192, 0.1070, 0.3575, 0.1146, 0.4016]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1032, 0.1793, 0.1803, 0.0604, 0.4768]], device='cuda:0')
# Done counter: 45
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0187, 0.1079, 0.3887, 0.1136, 0.3711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0141, 0.0697, 0.4181, 0.0731, 0.4251]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1554, 0.2246, 0.1919, 0.0593, 0.3688]], device='cuda:0')
# Done counter: 46
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0187, 0.1079, 0.3887, 0.1136, 0.3711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0150, 0.0691, 0.4028, 0.0675, 0.4456]], device='cuda:0')
# Done counter: 47
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Done counter: 48
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Done counter: 49
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 50
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0622, 0.2202, 0.0678, 0.6350]], device='cuda:0')
# Done counter: 51
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0148, 0.0665, 0.3185, 0.0735, 0.5267]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 52
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0157, 0.0678, 0.3720, 0.0683, 0.4763]], device='cuda:0')
# Done counter: 53
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2124, 0.0626, 0.6440]], device='cuda:0')
# Done counter: 54
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 55
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 56
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0247, 0.1753, 0.1894, 0.0659, 0.5447]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0252, 0.1327, 0.1313, 0.0296, 0.6812]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2463, 0.2814, 0.1240, 0.0441, 0.3042]], device='cuda:0')
# Done counter: 57
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2124, 0.0626, 0.6440]], device='cuda:0')
# Done counter: 58
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0214, 0.1223, 0.2694, 0.1250, 0.4619]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0212, 0.1299, 0.2084, 0.0725, 0.5680]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0373, 0.0961, 0.2084, 0.0640, 0.5943]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3162, 0.3320, 0.0897, 0.0321, 0.2300]], device='cuda:0')
# Done counter: 59
# Number of steps: 66
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3357, 0.2997, 0.1046, 0.0393, 0.2206]], device='cuda:0')
# Done counter: 60
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0161, 0.0779, 0.3376, 0.0850, 0.4834]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1554, 0.2246, 0.1919, 0.0593, 0.3688]], device='cuda:0')
# Done counter: 61
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 62
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0247, 0.1753, 0.1894, 0.0659, 0.5447]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.0901, 0.1729, 0.0452, 0.6714]], device='cuda:0')
# Done counter: 63
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0180, 0.0848, 0.2654, 0.0961, 0.5356]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0634, 0.1303, 0.2005, 0.0646, 0.5413]], device='cuda:0')
# Done counter: 64
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 65
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0166, 0.0663, 0.3078, 0.0682, 0.5411]], device='cuda:0')
# Done counter: 66
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.1137, 0.2650, 0.1172, 0.4836]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0164, 0.0720, 0.2489, 0.0826, 0.5801]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1030, 0.1673, 0.1982, 0.0640, 0.4674]], device='cuda:0')
# Done counter: 67
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0233, 0.1482, 0.2287, 0.0919, 0.5079]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.1472, 0.1297, 0.0307, 0.6719]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0711, 0.1739, 0.1649, 0.0488, 0.5413]], device='cuda:0')
# Done counter: 68
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0235, 0.1556, 0.2067, 0.0754, 0.5389]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0667, 0.2110, 0.0635, 0.6439]], device='cuda:0')
# Done counter: 69
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0243, 0.1596, 0.2326, 0.0981, 0.4854]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0851, 0.2311, 0.0803, 0.5865]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0367, 0.0948, 0.2252, 0.0656, 0.5777]], device='cuda:0')
# Done counter: 70
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0161, 0.0815, 0.2018, 0.0607, 0.6399]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 71
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Done counter: 72
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0235, 0.1651, 0.1752, 0.0553, 0.5810]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0426, 0.1308, 0.1737, 0.0490, 0.6039]], device='cuda:0')
# Done counter: 73
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0208, 0.1092, 0.2768, 0.1223, 0.4709]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0648, 0.2877, 0.0728, 0.5597]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3308, 0.2978, 0.1070, 0.0404, 0.2240]], device='cuda:0')
# Done counter: 74
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 75
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0185, 0.0997, 0.1650, 0.0431, 0.6737]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0373, 0.0961, 0.2084, 0.0640, 0.5943]], device='cuda:0')
# Done counter: 76
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0247, 0.1753, 0.1894, 0.0659, 0.5447]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0252, 0.1327, 0.1313, 0.0296, 0.6812]], device='cuda:0')
# Done counter: 77
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 78
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0607, 0.2313, 0.0704, 0.6227]], device='cuda:0')
# Done counter: 79
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2124, 0.0626, 0.6440]], device='cuda:0')
# Done counter: 80
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 81
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 82
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0185, 0.0997, 0.1650, 0.0431, 0.6737]], device='cuda:0')
# Done counter: 83
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0628, 0.2586, 0.0717, 0.5918]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 84
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Done counter: 85
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0607, 0.2313, 0.0704, 0.6227]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 86
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 87
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0192, 0.1070, 0.3575, 0.1146, 0.4016]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0166, 0.0663, 0.3078, 0.0682, 0.5411]], device='cuda:0')
# Done counter: 88
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0160, 0.0766, 0.1951, 0.0560, 0.6562]], device='cuda:0')
# Done counter: 89
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0212, 0.1194, 0.3106, 0.1307, 0.4180]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0161, 0.0779, 0.3376, 0.0850, 0.4834]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0604, 0.1294, 0.2396, 0.0666, 0.5040]], device='cuda:0')
# Done counter: 90
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0258, 0.1965, 0.1727, 0.0572, 0.5478]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0289, 0.1704, 0.1076, 0.0223, 0.6708]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0260, 0.1710, 0.1048, 0.0217, 0.6764]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1300, 0.2076, 0.1669, 0.0568, 0.4387]], device='cuda:0')
# Done counter: 91
# Number of steps: 64
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3088, 0.3165, 0.1227, 0.0415, 0.2105]], device='cuda:0')
# Done counter: 92
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0177, 0.0852, 0.2490, 0.0936, 0.5546]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0392, 0.1137, 0.1895, 0.0559, 0.6016]], device='cuda:0')
# Done counter: 93
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1554, 0.2246, 0.1919, 0.0593, 0.3688]], device='cuda:0')
# Done counter: 94
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0223, 0.1407, 0.2132, 0.0778, 0.5460]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0213, 0.0730, 0.2055, 0.0597, 0.6406]], device='cuda:0')
# Done counter: 95
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 96
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 97
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 98
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0223, 0.1407, 0.2132, 0.0778, 0.5460]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0159, 0.0686, 0.2347, 0.0784, 0.6023]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1939, 0.2453, 0.1670, 0.0556, 0.3383]], device='cuda:0')
# Done counter: 99
# Number of steps: 64
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 100
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 101
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 102
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0208, 0.1210, 0.3395, 0.1302, 0.3884]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0152, 0.0670, 0.2278, 0.0737, 0.6163]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 103
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0278, 0.2079, 0.2200, 0.0973, 0.4469]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0172, 0.0805, 0.2855, 0.0903, 0.5265]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1032, 0.1793, 0.1803, 0.0604, 0.4768]], device='cuda:0')
# Done counter: 104
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0249, 0.1602, 0.2811, 0.1582, 0.3756]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0201, 0.1144, 0.2256, 0.0823, 0.5576]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0392, 0.1137, 0.1895, 0.0559, 0.6016]], device='cuda:0')
# Done counter: 105
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0187, 0.1152, 0.4259, 0.1186, 0.3217]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0144, 0.0690, 0.3840, 0.0736, 0.4590]], device='cuda:0')
# Done counter: 106
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0215, 0.1173, 0.2828, 0.1305, 0.4478]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0161, 0.0781, 0.2246, 0.0744, 0.6068]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1612, 0.2233, 0.1595, 0.0558, 0.4002]], device='cuda:0')
# Done counter: 107
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2382, 0.2673, 0.1333, 0.0480, 0.3132]], device='cuda:0')
# Done counter: 108
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0152, 0.0670, 0.2278, 0.0737, 0.6163]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1629, 0.2145, 0.1634, 0.0577, 0.4014]], device='cuda:0')
# Done counter: 109
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0173, 0.0875, 0.1798, 0.0492, 0.6662]], device='cuda:0')
# Done counter: 110
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 111
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0192, 0.1070, 0.3575, 0.1146, 0.4016]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0223, 0.1407, 0.2132, 0.0778, 0.5460]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0248, 0.0955, 0.1777, 0.0477, 0.6543]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3020, 0.3076, 0.1031, 0.0374, 0.2498]], device='cuda:0')
# Done counter: 112
# Number of steps: 74
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.4209, 0.3186, 0.0807, 0.0316, 0.1483]], device='cuda:0')
# Done counter: 113
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0192, 0.1070, 0.3575, 0.1146, 0.4016]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0156, 0.0704, 0.2973, 0.0785, 0.5382]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1554, 0.2246, 0.1919, 0.0593, 0.3688]], device='cuda:0')
# Done counter: 114
# Number of steps: 58
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0187, 0.1079, 0.3887, 0.1136, 0.3711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0166, 0.0663, 0.3078, 0.0682, 0.5411]], device='cuda:0')
# Done counter: 115
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2855, 0.3607, 0.0817, 0.0277, 0.2444]], device='cuda:0')
# Done counter: 116
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Done counter: 117
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0607, 0.2313, 0.0704, 0.6227]], device='cuda:0')
# Done counter: 118
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2124, 0.0626, 0.6440]], device='cuda:0')
# Done counter: 119
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0651, 0.2774, 0.0675, 0.5730]], device='cuda:0')
# Done counter: 120
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1554, 0.2246, 0.1919, 0.0593, 0.3688]], device='cuda:0')
# Done counter: 121
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 122
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0246, 0.1679, 0.2107, 0.0807, 0.5161]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0185, 0.0997, 0.1650, 0.0431, 0.6737]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1612, 0.2233, 0.1595, 0.0558, 0.4002]], device='cuda:0')
# Done counter: 123
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0220, 0.1029, 0.1583, 0.0394, 0.6773]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2092, 0.3570, 0.0889, 0.0276, 0.3173]], device='cuda:0')
# Done counter: 124
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0193, 0.1151, 0.3946, 0.1205, 0.3506]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0153, 0.0734, 0.3605, 0.0792, 0.4716]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 125
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2488, 0.0664, 0.6038]], device='cuda:0')
# Done counter: 126
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0219, 0.1302, 0.2469, 0.1041, 0.4970]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0622, 0.2202, 0.0678, 0.6350]], device='cuda:0')
# Done counter: 127
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.0901, 0.1729, 0.0452, 0.6714]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2382, 0.2673, 0.1333, 0.0480, 0.3132]], device='cuda:0')
# Done counter: 128
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 129
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0219, 0.1302, 0.2469, 0.1041, 0.4970]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0667, 0.2110, 0.0635, 0.6439]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 130
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# ...
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0192, 0.1070, 0.3575, 0.1146, 0.4016]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0148, 0.0665, 0.3185, 0.0735, 0.5267]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1042, 0.1706, 0.1862, 0.0629, 0.4760]], device='cuda:0')
# Done counter: 169
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0202, 0.1132, 0.3337, 0.1226, 0.4103]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0628, 0.2586, 0.0717, 0.5918]], device='cuda:0')
# Done counter: 170
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3308, 0.2978, 0.1070, 0.0404, 0.2240]], device='cuda:0')
# Done counter: 171
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0174, 0.0636, 0.2124, 0.0626, 0.6440]], device='cuda:0')
# Done counter: 172
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0187, 0.1079, 0.3887, 0.1136, 0.3711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0607, 0.2313, 0.0704, 0.6227]], device='cuda:0')
# Done counter: 173
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 174
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 175
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 176
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0206, 0.1115, 0.3046, 0.1227, 0.4406]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0679, 0.3507, 0.0737, 0.4930]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 177
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 178
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0162, 0.0672, 0.3397, 0.0686, 0.5084]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 179
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0180, 0.0970, 0.2142, 0.0710, 0.5998]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1030, 0.1673, 0.1982, 0.0640, 0.4674]], device='cuda:0')
# Done counter: 180
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0192, 0.1070, 0.3575, 0.1146, 0.4016]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0166, 0.0663, 0.3078, 0.0682, 0.5411]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1629, 0.2145, 0.1634, 0.0577, 0.4014]], device='cuda:0')
# Done counter: 181
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 182
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1038, 0.2981, 0.1150, 0.4633]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0679, 0.3507, 0.0737, 0.4930]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 183
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0219, 0.1302, 0.2469, 0.1041, 0.4970]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0160, 0.0727, 0.2351, 0.0800, 0.5962]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1612, 0.2158, 0.1734, 0.0591, 0.3905]], device='cuda:0')
# Done counter: 184
# Number of steps: 58
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0270, 0.2035, 0.1962, 0.0752, 0.4982]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0152, 0.0716, 0.2179, 0.0688, 0.6265]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 185
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0236, 0.1171, 0.1445, 0.0343, 0.6806]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1299, 0.2773, 0.1198, 0.0350, 0.4378]], device='cuda:0')
# Done counter: 186
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0247, 0.1753, 0.1894, 0.0659, 0.5447]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.0901, 0.1729, 0.0452, 0.6714]], device='cuda:0')
# Done counter: 187
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.1137, 0.2650, 0.1172, 0.4836]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0622, 0.2202, 0.0678, 0.6350]], device='cuda:0')
# Done counter: 188
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 189
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 190
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0188, 0.1175, 0.1565, 0.0408, 0.6663]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1629, 0.2145, 0.1634, 0.0577, 0.4014]], device='cuda:0')
# Done counter: 191
# Number of steps: 48
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0190, 0.0785, 0.1880, 0.0516, 0.6629]], device='cuda:0')
# Done counter: 192
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1057, 0.3273, 0.1151, 0.4324]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 193
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0179, 0.1044, 0.1710, 0.0467, 0.6599]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1764, 0.2696, 0.1316, 0.0431, 0.3793]], device='cuda:0')
# Done counter: 194
# Number of steps: 50
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0212, 0.1194, 0.3106, 0.1307, 0.4180]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0152, 0.0670, 0.2278, 0.0737, 0.6163]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2382, 0.2673, 0.1333, 0.0480, 0.3132]], device='cuda:0')
# Done counter: 195
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0219, 0.1302, 0.2469, 0.1041, 0.4970]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0152, 0.0670, 0.2278, 0.0737, 0.6163]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2390, 0.2630, 0.1369, 0.0496, 0.3115]], device='cuda:0')
# Done counter: 196
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 197
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0179, 0.1044, 0.1710, 0.0467, 0.6599]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2382, 0.2673, 0.1333, 0.0480, 0.3132]], device='cuda:0')
# Done counter: 198
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0206, 0.1115, 0.3046, 0.1227, 0.4406]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0149, 0.0628, 0.2586, 0.0717, 0.5918]], device='cuda:0')
# Done counter: 199
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0248, 0.1612, 0.2578, 0.1256, 0.4305]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0198, 0.1085, 0.2486, 0.0998, 0.5232]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0213, 0.0730, 0.2055, 0.0597, 0.6406]], device='cuda:0')
# Done counter: 200
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0193, 0.1151, 0.3946, 0.1205, 0.3506]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0147, 0.0679, 0.3507, 0.0737, 0.4930]], device='cuda:0')
# Done counter: 201
# Number of steps: 44
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0219, 0.1302, 0.2469, 0.1041, 0.4970]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0185, 0.0997, 0.1650, 0.0431, 0.6737]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.2610, 0.3075, 0.1089, 0.0379, 0.2847]], device='cuda:0')
# Done counter: 202
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0176, 0.0618, 0.2222, 0.0651, 0.6333]], device='cuda:0')
# Done counter: 203
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0222, 0.1374, 0.2243, 0.0859, 0.5302]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0220, 0.1029, 0.1583, 0.0394, 0.6773]], device='cuda:0')
# Done counter: 204
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0209, 0.1206, 0.2422, 0.0973, 0.5190]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0210, 0.1278, 0.1375, 0.0326, 0.6811]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.3357, 0.2997, 0.1046, 0.0393, 0.2206]], device='cuda:0')
# Done counter: 205
# Number of steps: 46
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0205, 0.1137, 0.2650, 0.1172, 0.4836]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0164, 0.0743, 0.2769, 0.0838, 0.5486]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.1554, 0.2246, 0.1919, 0.0593, 0.3688]], device='cuda:0')
# Done counter: 206
# Number of steps: 54
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0208, 0.1092, 0.2768, 0.1223, 0.4709]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0172, 0.0782, 0.2573, 0.0892, 0.5580]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0711, 0.1739, 0.1649, 0.0488, 0.5413]], device='cuda:0')
# Done counter: 207
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0196, 0.1054, 0.2601, 0.1096, 0.5053]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0175, 0.0682, 0.2037, 0.0587, 0.6519]], device='cuda:0')
# Done counter: 208
# Number of steps: 42
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0258, 0.1723, 0.2604, 0.1331, 0.4085]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0179, 0.0925, 0.2373, 0.0866, 0.5658]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0660, 0.1525, 0.1814, 0.0562, 0.5439]], device='cuda:0')
# Done counter: 209
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0192, 0.1070, 0.3575, 0.1146, 0.4016]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0188, 0.0917, 0.2732, 0.1033, 0.5130]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0342, 0.0967, 0.2785, 0.0669, 0.5237]], device='cuda:0')
# Done counter: 210
# Number of steps: 56
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0187, 0.1079, 0.3887, 0.1136, 0.3711]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0170, 0.0824, 0.3153, 0.0909, 0.4943]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0992, 0.1732, 0.2190, 0.0643, 0.4443]], device='cuda:0')
# Done counter: 211
# Number of steps: 52
# Boltzmann probabilities: tensor([[0.0253, 0.1653, 0.2922, 0.1795, 0.3377]], device='cuda:0')
# Boltzmann probabilities: tensor([[0.0200, 0.1015, 0.2702, 0.1143, 0.4940]], device='cuda:0')
# average number of steps: 47
# max: 74
# min: 42
